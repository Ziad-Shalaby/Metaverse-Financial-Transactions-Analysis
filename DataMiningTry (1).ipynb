# %%
# To import the libraries and data:
import pandas as pd
import warnings
import numpy as np
from sklearn_extra.cluster import KMedoids

total_data = pd.read_csv("C:\\Users\\Ziad\Downloads\\Downloads\\Just Study!\\Data Mining\\project\\Financial_ Application_ Behavior_ Dataset.csv")
data = total_data.loc[0:5999]

# %%
data.head()
# Out:
#      user               first_open  dayofweek       hour  age  \
# 0  235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1  333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2  254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3  234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4   51549  2013-02-26 18:50:48.661          1   18:00:00   31
#
#                                          screen_list  numscreens  minigame  \
# 0  idscreen,joinscreen,Cycle,product_review,ScanP...          15         0
# 1  joinscreen,product_review,product_review2,Scan...          13         0
# 2                                  Splash,Cycle,Loan           3         0
# 3  product_review,Home,product_review,Loan3,Finan...          40         0
# 4  idscreen,joinscreen,Cycle,Credit3Container,Sca...          32         0
#
#    used_premium_feature  enrolled            enrolled_date  liked
# 0                     0         0                      NaN      0
# 1                     0         0                      NaN      0
# 2                     1         0                      NaN      1
# 3                     0         1  2013-07-05 16:11:49.513      0
# 4                     0         1  2013-02-26 18:56:37.841      1

# %%
# To find and rename the unnamed coulumns:
unnamed_cols = data.columns[data.columns.str.contains('Unnamed')]

if len(unnamed_cols) > 0:
    print("Unnamed columns found:", unnamed_cols.tolist())
else:
    print("No unnamed columns found.")

# No unnamed columns so, we won't change anything :)
# Out:
# No unnamed columns found.

# %%
# To check the data types & change it if we need:
data.dtypes
# Out:
# user                     int64
# first_open              object
# dayofweek                int64
# hour                    object
# age                      int64
# screen_list             object
# numscreens               int64
# minigame                 int64
# used_premium_feature     int64
# enrolled                 int64
# enrolled_date           object
# liked                    int64
# dtype: object

# %%
#To change the type of the column we may need:
warnings.filterwarnings('ignore', category=UserWarning)
data['first_open'] = pd.to_datetime(data['first_open'])
data['hour'] = pd.to_timedelta(data['hour'])
data['enrolled_date'] = pd.to_datetime(data['enrolled_date'])
data.dtypes
# Out:
# C:\Users\Ziad\AppData\Local\Temp\ipykernel_3384\3992208812.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['first_open'] = pd.to_datetime(data['first_open'])
# C:\Users\Ziad\AppData\Local\Temp\ipykernel_3384\3992208812.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['hour'] = pd.to_timedelta(data['hour'])
# C:\Users\Ziad\AppData\Local\Temp\ipykernel_3384\3992208812.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['enrolled_date'] = pd.to_datetime(data['enrolled_date'])
# user                              int64
# first_open               datetime64[ns]
# dayofweek                         int64
# hour                    timedelta64[ns]
# age                               int64
# screen_list                      object
# numscreens                        int64
# minigame                          int64
# used_premium_feature              int64
# enrolled                          int64
# enrolled_date            datetime64[ns]
# liked                             int64
# dtype: object

# %%
# To check the null values & drop or filling them if we need:
data.isnull().sum()
# Out:
# user                       0
# first_open                 0
# dayofweek                  0
# hour                       0
# age                        0
# screen_list                0
# numscreens                 0
# minigame                   0
# used_premium_feature       0
# enrolled                   0
# enrolled_date           2255
# liked                      0
# dtype: int64

# %%
# we found null values in enrolled_date column so we will drop it cause we don't have the info to fill them:
warnings.filterwarnings('ignore', category=UserWarning)
data.dropna(inplace = True)
data
# Out:
# C:\Users\Ziad\AppData\Local\Temp\ipykernel_3384\1901956804.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace = True)
#         user              first_open  dayofweek            hour  age  \
# 3     234192 2013-07-05 16:08:46.354          4 0 days 16:00:00   28
# 4      51549 2013-02-26 18:50:48.661          1 0 days 18:00:00   31
# 5      56480 2013-04-03 09:58:15.752          2 0 days 09:00:00   20
# 8     372004 2013-03-20 14:22:01.569          2 0 days 14:00:00   29
# 9     338013 2013-04-26 18:22:16.013          4 0 days 18:00:00   26
# ...      ...                     ...        ...             ...  ...
# 5991  352309 2013-05-29 20:02:25.184          2 0 days 20:00:00   26
# 5994  246740 2013-04-16 19:43:23.964          1 0 days 19:00:00   22
# 5995  260880 2013-04-28 12:50:38.624          6 0 days 12:00:00   40
# 5996   11371 2013-05-10 07:56:18.381          4 0 days 07:00:00   24
# 5998  110406 2012-12-07 03:27:16.423          4 0 days 03:00:00   47
#
#                                             screen_list  numscreens  minigame  \
# 3     product_review,Home,product_review,Loan3,Finan...          40         0
# 4     idscreen,joinscreen,Cycle,Credit3Container,Sca...          32         0
# 5     idscreen,Cycle,Home,ScanPreview,VerifyPhone,Ve...          14         0
# 8     product_review,product_review2,ScanPreview,Ver...          33         1
# 9     Home,Loan2,product_review,product_review,produ...          19         0
# ...                                                 ...         ...       ...
# 5991  Splash,idscreen,Cycle,product_review,Home,prod...          20         0
# 5994  Cycle,Home,Loan2,product_review,product_review...          18         0
# 5995  Home,product_review,product_review,product_rev...          17         1
# 5996  Loan2,product_review,product_review,VerifyDate...          13         0
# 5998  joinscreen,Home,Loan2,product_review,product_r...          39         0
#
#       used_premium_feature  enrolled           enrolled_date  liked
# 3                        0         1 2013-07-05 16:11:49.513      0
# 4                        0         1 2013-02-26 18:56:37.841      1
# 5                        0         1 2013-04-03 09:59:03.291      0
# 8                        1         1 2013-04-27 22:24:54.542      0
# 9                        0         1 2013-04-26 18:31:58.923      0
# ...                    ...       ...                     ...    ...
# 5991                     1         1 2013-05-29 20:06:13.172      0
# 5994                     0         1 2013-04-16 19:46:48.400      0
# 5995                     0         1 2013-04-28 13:02:51.318      0
# 5996                     1         1 2013-06-18 02:45:25.143      0
# 5998                     1         1 2013-04-01 16:53:05.225      0
#
# [3745 rows x 12 columns]

# %%
# To check the duplicates and drop them:
data.duplicated().sum()
# Out:
# 0

# %%
# we found duplicated values so, we will drop it: 
warnings.filterwarnings('ignore', category=UserWarning)
data.drop_duplicates(inplace = True)
data
# Out:
# C:\Users\Ziad\AppData\Local\Temp\ipykernel_3384\1025342544.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace = True)
#         user              first_open  dayofweek            hour  age  \
# 3     234192 2013-07-05 16:08:46.354          4 0 days 16:00:00   28
# 4      51549 2013-02-26 18:50:48.661          1 0 days 18:00:00   31
# 5      56480 2013-04-03 09:58:15.752          2 0 days 09:00:00   20
# 8     372004 2013-03-20 14:22:01.569          2 0 days 14:00:00   29
# 9     338013 2013-04-26 18:22:16.013          4 0 days 18:00:00   26
# ...      ...                     ...        ...             ...  ...
# 5991  352309 2013-05-29 20:02:25.184          2 0 days 20:00:00   26
# 5994  246740 2013-04-16 19:43:23.964          1 0 days 19:00:00   22
# 5995  260880 2013-04-28 12:50:38.624          6 0 days 12:00:00   40
# 5996   11371 2013-05-10 07:56:18.381          4 0 days 07:00:00   24
# 5998  110406 2012-12-07 03:27:16.423          4 0 days 03:00:00   47
#
#                                             screen_list  numscreens  minigame  \
# 3     product_review,Home,product_review,Loan3,Finan...          40         0
# 4     idscreen,joinscreen,Cycle,Credit3Container,Sca...          32         0
# 5     idscreen,Cycle,Home,ScanPreview,VerifyPhone,Ve...          14         0
# 8     product_review,product_review2,ScanPreview,Ver...          33         1
# 9     Home,Loan2,product_review,product_review,produ...          19         0
# ...                                                 ...         ...       ...
# 5991  Splash,idscreen,Cycle,product_review,Home,prod...          20         0
# 5994  Cycle,Home,Loan2,product_review,product_review...          18         0
# 5995  Home,product_review,product_review,product_rev...          17         1
# 5996  Loan2,product_review,product_review,VerifyDate...          13         0
# 5998  joinscreen,Home,Loan2,product_review,product_r...          39         0
#
#       used_premium_feature  enrolled           enrolled_date  liked
# 3                        0         1 2013-07-05 16:11:49.513      0
# 4                        0         1 2013-02-26 18:56:37.841      1
# 5                        0         1 2013-04-03 09:59:03.291      0
# 8                        1         1 2013-04-27 22:24:54.542      0
# 9                        0         1 2013-04-26 18:31:58.923      0
# ...                    ...       ...                     ...    ...
# 5991                     1         1 2013-05-29 20:06:13.172      0
# 5994                     0         1 2013-04-16 19:46:48.400      0
# 5995                     0         1 2013-04-28 13:02:51.318      0
# 5996                     1         1 2013-06-18 02:45:25.143      0
# 5998                     1         1 2013-04-01 16:53:05.225      0
#
# [3745 rows x 12 columns]

# %%
# The K_Medoids Algorithm: 
columns_var = data[['age','user']]
data_array = np.array(columns_var)
k = 2
counter0 = 0
counter1 = 0
k_mediods = KMedoids(n_clusters = k).fit(data_array)
clusters = k_mediods.cluster_centers_
labels = k_mediods.labels_

for i in range(k):
    print("[[{:0.1f}, {:d}]]".format(clusters[i][0], int(clusters[i][1])))

print(labels)

for j in range(k) : 
    for i in range(len(data_array)):    
        if k_mediods.labels_[i] == j:
            x = data_array[i]
            print('Cluster ' , j, ':', x)
            if j == 0:
                counter0 += 1

            elif j == 1:
                counter1 += 1
# Out:
# [[48.0, 93587]]
# [[23.0, 278430]]
# [1 0 0 ... 1 0 0]
# Cluster  0 : [   31 51549]
# Cluster  0 : [   20 56480]
# Cluster  0 : [   39 43555]
# Cluster  0 : [    55 141402]
# Cluster  0 : [   25 54931]
# Cluster  0 : [    28 165432]
# Cluster  0 : [    31 110461]
# Cluster  0 : [    48 180427]
# Cluster  0 : [  22 9810]
# Cluster  0 : [   35 85089]
# Cluster  0 : [    32 143818]
# Cluster  0 : [   23 95362]
# Cluster  0 : [   31 84738]
# Cluster  0 : [   26 74128]
# Cluster  0 : [   21 15995]
# Cluster  0 : [    24 133014]
# Cluster  0 : [    23 133810]
# Cluster  0 : [    25 171351]
# Cluster  0 : [   40 23425]
# Cluster  0 : [   33 21700]
# Cluster  0 : [   21 17739]
# Cluster  0 : [   57 69760]
# Cluster  0 : [   20 34071]
# Cluster  0 : [   31 44814]
# Cluster  0 : [    27 138117]
# Cluster  0 : [    33 150614]
# Cluster  0 : [   37 43620]
# Cluster  0 : [    45 185092]
# Cluster  0 : [    22 149499]
# Cluster  0 : [   28 58451]
# Cluster  0 : [    35 163715]
# Cluster  0 : [    21 137484]
# Cluster  0 : [   25 39677]
# Cluster  0 : [    34 123984]
# Cluster  0 : [    24 184032]
# Cluster  0 : [   31 60702]
# Cluster  0 : [    27 125898]
# Cluster  0 : [    35 143018]
# Cluster  0 : [   26 40978]
# Cluster  0 : [    20 172249]
# Cluster  0 : [   30 22652]
# Cluster  0 : [    23 127958]
# Cluster  0 : [   30 69353]
# Cluster  0 : [   30 25627]
# Cluster  0 : [   34 72135]
# Cluster  0 : [   43 43535]
# Cluster  0 : [    21 182086]
# Cluster  0 : [    33 151404]
# Cluster  0 : [    33 120380]
# Cluster  0 : [    23 179917]
# Cluster  0 : [    20 130555]
# Cluster  0 : [   22 15106]
# Cluster  0 : [    39 105984]
# Cluster  0 : [    31 155491]
# Cluster  0 : [   17 35333]
# Cluster  0 : [    31 169339]
# Cluster  0 : [    24 177859]
# Cluster  0 : [   32 27513]
# Cluster  0 : [    26 109154]
# Cluster  0 : [    29 154536]
# Cluster  0 : [    20 116034]
# Cluster  0 : [    22 167756]
# Cluster  0 : [   46 56270]
# Cluster  0 : [    31 144393]
# Cluster  0 : [   24 89726]
# Cluster  0 : [   38 62035]
# Cluster  0 : [   27 25410]
# Cluster  0 : [   24 93446]
# Cluster  0 : [    29 133446]
# Cluster  0 : [   26 94214]
# Cluster  0 : [    36 135746]
# Cluster  0 : [   21 12895]
# Cluster  0 : [    21 116493]
# Cluster  0 : [  30 7914]
# Cluster  0 : [    17 145742]
# Cluster  0 : [    23 182226]
# Cluster  0 : [    24 133478]
# Cluster  0 : [   41 99535]
# Cluster  0 : [   24 88818]
# Cluster  0 : [   24 74986]
# Cluster  0 : [    28 141543]
# Cluster  0 : [    23 153178]
# Cluster  0 : [   43 47893]
# Cluster  0 : [   28 81825]
# Cluster  0 : [   44 32977]
# Cluster  0 : [    19 132356]
# Cluster  0 : [   23 84550]
# Cluster  0 : [   52 72928]
# Cluster  0 : [   48 84955]
# Cluster  0 : [    19 176032]
# Cluster  0 : [   31 81054]
# Cluster  0 : [    38 119550]
# Cluster  0 : [   26 99595]
# Cluster  0 : [   53 11366]
# Cluster  0 : [   33 26534]
# Cluster  0 : [   34 22724]
# Cluster  0 : [   19 22623]
# Cluster  0 : [    33 152107]
# Cluster  0 : [   40 96475]
# Cluster  0 : [    24 128061]
# Cluster  0 : [    37 155464]
# Cluster  0 : [    31 128593]
# Cluster  0 : [   19 79140]
# Cluster  0 : [   22 25387]
# Cluster  0 : [    28 144820]
# Cluster  0 : [   19 53795]
# Cluster  0 : [  19 2883]
# Cluster  0 : [    41 145673]
# Cluster  0 : [   21 23306]
# Cluster  0 : [   53 53596]
# Cluster  0 : [    28 124230]
# Cluster  0 : [    31 136619]
# Cluster  0 : [    18 116811]
# Cluster  0 : [    24 170136]
# Cluster  0 : [   50 73851]
# Cluster  0 : [   25 32801]
# Cluster  0 : [    24 175259]
# Cluster  0 : [    26 155878]
# Cluster  0 : [    44 182135]
# Cluster  0 : [   24 46126]
# Cluster  0 : [    16 107443]
# Cluster  0 : [    28 160626]
# Cluster  0 : [    43 100405]
# Cluster  0 : [    24 128888]
# Cluster  0 : [   18 92634]
# Cluster  0 : [    30 133018]
# Cluster  0 : [   50 60228]
# Cluster  0 : [    37 109856]
# Cluster  0 : [    70 122398]
# Cluster  0 : [    30 125696]
# Cluster  0 : [    29 131306]
# Cluster  0 : [   20 90792]
# Cluster  0 : [   22 54550]
# Cluster  0 : [   56 84304]
# Cluster  0 : [    34 173911]
# Cluster  0 : [   18 97134]
# Cluster  0 : [   26 46254]
# Cluster  0 : [    33 145884]
# Cluster  0 : [   21 41405]
# Cluster  0 : [   38 25668]
# Cluster  0 : [   28 90918]
# Cluster  0 : [    30 100779]
# Cluster  0 : [    25 110036]
# Cluster  0 : [    52 146769]
# Cluster  0 : [    30 116846]
# Cluster  0 : [   21 50081]
# Cluster  0 : [    22 143289]
# Cluster  0 : [    51 132805]
# Cluster  0 : [    42 109501]
# Cluster  0 : [    24 120305]
# Cluster  0 : [   30 14591]
# Cluster  0 : [   42 64660]
# Cluster  0 : [   40 61152]
# Cluster  0 : [    21 173245]
# Cluster  0 : [   32 40281]
# Cluster  0 : [    21 174301]
# Cluster  0 : [    20 103177]
# Cluster  0 : [    22 182074]
# Cluster  0 : [27 96]
# Cluster  0 : [    54 121756]
# Cluster  0 : [   53 53079]
# Cluster  0 : [   19 81478]
# Cluster  0 : [    19 128664]
# Cluster  0 : [   26 70872]
# Cluster  0 : [   24 52800]
# Cluster  0 : [    28 171845]
# Cluster  0 : [    21 109527]
# Cluster  0 : [    22 124855]
# Cluster  0 : [    51 171438]
# Cluster  0 : [   26 94082]
# Cluster  0 : [ 22 789]
# Cluster  0 : [   55 30744]
# Cluster  0 : [  40 9609]
# Cluster  0 : [    37 141241]
# Cluster  0 : [    48 153977]
# Cluster  0 : [   25 19993]
# Cluster  0 : [    19 131036]
# Cluster  0 : [   24 17604]
# Cluster  0 : [    19 116822]
# Cluster  0 : [   20 56705]
# Cluster  0 : [   52 26700]
# Cluster  0 : [   37 79609]
# Cluster  0 : [   25 62723]
# Cluster  0 : [    45 111770]
# Cluster  0 : [   46 30567]
# Cluster  0 : [   28 77449]
# Cluster  0 : [    25 112215]
# Cluster  0 : [    32 155768]
# Cluster  0 : [    26 122894]
# Cluster  0 : [    21 134567]
# Cluster  0 : [   18 93816]
# Cluster  0 : [   36 17398]
# Cluster  0 : [    38 152270]
# Cluster  0 : [  26 4332]
# Cluster  0 : [    45 157131]
# Cluster  0 : [   30 71978]
# Cluster  0 : [   27 22040]
# Cluster  0 : [   38 58716]
# Cluster  0 : [  25 1575]
# Cluster  0 : [   22 84441]
# Cluster  0 : [   26 10236]
# Cluster  0 : [   44 72964]
# Cluster  0 : [    38 173023]
# Cluster  0 : [    38 150483]
# Cluster  0 : [   21 84713]
# Cluster  0 : [   21 77200]
# Cluster  0 : [    58 126210]
# Cluster  0 : [   39 31749]
# Cluster  0 : [    22 101613]
# Cluster  0 : [    28 116473]
# Cluster  0 : [  31 1763]
# Cluster  0 : [   37 51053]
# Cluster  0 : [   27 15484]
# Cluster  0 : [   18 17065]
# Cluster  0 : [   22 69980]
# Cluster  0 : [    60 139286]
# Cluster  0 : [    24 171366]
# Cluster  0 : [    25 132348]
# Cluster  0 : [   48 93587]
# Cluster  0 : [   47 78443]
# Cluster  0 : [   46 86519]
# Cluster  0 : [    19 113104]
# Cluster  0 : [   68 39912]
# Cluster  0 : [   26 14574]
# Cluster  0 : [   23 44096]
# Cluster  0 : [   27 21411]
# Cluster  0 : [    41 184407]
# Cluster  0 : [  38 2325]
# Cluster  0 : [    38 124051]
# Cluster  0 : [   19 88036]
# Cluster  0 : [    26 148586]
# Cluster  0 : [    29 181171]
# Cluster  0 : [    40 166575]
# Cluster  0 : [   37 71929]
# Cluster  0 : [    31 104706]
# Cluster  0 : [    20 167751]
# Cluster  0 : [   22 86403]
# Cluster  0 : [   42 13224]
# Cluster  0 : [   37 47405]
# Cluster  0 : [   57 11160]
# Cluster  0 : [    27 132255]
# Cluster  0 : [   21 35839]
# Cluster  0 : [   24 40340]
# Cluster  0 : [    17 181690]
# Cluster  0 : [   36 74340]
# Cluster  0 : [    19 158802]
# Cluster  0 : [    27 136785]
# Cluster  0 : [   28 60361]
# Cluster  0 : [    20 100288]
# Cluster  0 : [    23 158562]
# Cluster  0 : [    31 121906]
# Cluster  0 : [    36 157486]
# Cluster  0 : [   38 22204]
# Cluster  0 : [    38 115377]
# Cluster  0 : [    17 135339]
# Cluster  0 : [   31 18463]
# Cluster  0 : [   23 59529]
# Cluster  0 : [   45 18033]
# Cluster  0 : [    28 130070]
# Cluster  0 : [   24 31874]
# Cluster  0 : [    20 107534]
# Cluster  0 : [    26 136636]
# Cluster  0 : [    36 166960]
# Cluster  0 : [    35 128652]
# Cluster  0 : [    26 131619]
# Cluster  0 : [   53 92788]
# Cluster  0 : [    42 123134]
# Cluster  0 : [   32 58597]
# Cluster  0 : [    22 148080]
# Cluster  0 : [   26 42665]
# Cluster  0 : [   23 30879]
# Cluster  0 : [    20 141159]
# Cluster  0 : [   22 58171]
# Cluster  0 : [    51 119027]
# Cluster  0 : [   27 82805]
# Cluster  0 : [    40 149622]
# Cluster  0 : [   33 69199]
# Cluster  0 : [  37 5178]
# Cluster  0 : [   27 83186]
# Cluster  0 : [    22 118296]
# Cluster  0 : [    25 100543]
# Cluster  0 : [   21 22064]
# Cluster  0 : [    28 176282]
# Cluster  0 : [    28 130787]
# Cluster  0 : [   30 21827]
# Cluster  0 : [    30 110722]
# Cluster  0 : [   26 45904]
# Cluster  0 : [    24 154793]
# Cluster  0 : [   28 13954]
# Cluster  0 : [    41 124724]
# Cluster  0 : [   28 13564]
# Cluster  0 : [   19 64570]
# Cluster  0 : [    44 180577]
# Cluster  0 : [    56 179451]
# Cluster  0 : [    24 172078]
# Cluster  0 : [   32 62320]
# Cluster  0 : [   21 56449]
# Cluster  0 : [   42 68259]
# Cluster  0 : [   24 38926]
# Cluster  0 : [    28 167622]
# Cluster  0 : [    53 107881]
# Cluster  0 : [   31 94129]
# Cluster  0 : [   27 70869]
# Cluster  0 : [    43 151561]
# Cluster  0 : [    39 146051]
# Cluster  0 : [    20 125542]
# Cluster  0 : [   35 57642]
# Cluster  0 : [    50 173747]
# Cluster  0 : [   25 25562]
# Cluster  0 : [    24 171916]
# Cluster  0 : [   24 20728]
# Cluster  0 : [    50 163067]
# Cluster  0 : [   17 26596]
# Cluster  0 : [    39 107712]
# Cluster  0 : [   25 35602]
# Cluster  0 : [    33 168485]
# Cluster  0 : [    20 155185]
# Cluster  0 : [   32 42112]
# Cluster  0 : [    28 121080]
# Cluster  0 : [   24 57252]
# Cluster  0 : [   29 62059]
# Cluster  0 : [    23 114466]
# Cluster  0 : [   21 55217]
# Cluster  0 : [    44 175569]
# Cluster  0 : [    51 170584]
# Cluster  0 : [   23 41479]
# Cluster  0 : [    30 120415]
# Cluster  0 : [    21 179495]
# Cluster  0 : [    36 185900]
# Cluster  0 : [    30 169775]
# Cluster  0 : [    38 126325]
# Cluster  0 : [    40 131056]
# Cluster  0 : [   49 95057]
# Cluster  0 : [    33 104129]
# Cluster  0 : [    36 108237]
# Cluster  0 : [   17 80508]
# Cluster  0 : [   50 91289]
# Cluster  0 : [    33 103370]
# Cluster  0 : [   28 12013]
# Cluster  0 : [    47 176213]
# Cluster  0 : [    35 102333]
# Cluster  0 : [   42 74450]
# Cluster  0 : [   48 82325]
# Cluster  0 : [   33 43807]
# Cluster  0 : [   39 23208]
# Cluster  0 : [    31 176759]
# Cluster  0 : [    21 116245]
# Cluster  0 : [   22 32907]
# Cluster  0 : [    32 176238]
# Cluster  0 : [   20 22165]
# Cluster  0 : [    21 160895]
# Cluster  0 : [   45 75768]
# Cluster  0 : [    34 152362]
# Cluster  0 : [   62 81727]
# Cluster  0 : [   19 17418]
# Cluster  0 : [   44 93771]
# Cluster  0 : [    68 184077]
# Cluster  0 : [   18 34433]
# Cluster  0 : [   20 69731]
# Cluster  0 : [   20 21104]
# Cluster  0 : [   20 19706]
# Cluster  0 : [    34 168688]
# Cluster  0 : [   26 73815]
# Cluster  0 : [   20 76492]
# Cluster  0 : [   25 40996]
# Cluster  0 : [   28 79545]
# Cluster  0 : [    47 175192]
# Cluster  0 : [    21 153581]
# Cluster  0 : [  22 3922]
# Cluster  0 : [   18 79668]
# Cluster  0 : [   22 89696]
# Cluster  0 : [   21 66898]
# Cluster  0 : [   28 29217]
# Cluster  0 : [   39 40877]
# Cluster  0 : [    21 184532]
# Cluster  0 : [   21 63026]
# Cluster  0 : [    18 171221]
# Cluster  0 : [    25 149788]
# Cluster  0 : [    35 170482]
# Cluster  0 : [    19 124403]
# Cluster  0 : [    25 184197]
# Cluster  0 : [    30 142134]
# Cluster  0 : [    36 150460]
# Cluster  0 : [   36 50577]
# Cluster  0 : [    33 144503]
# Cluster  0 : [    34 113079]
# Cluster  0 : [    41 153377]
# Cluster  0 : [  34 7532]
# Cluster  0 : [    39 150511]
# Cluster  0 : [   35 40902]
# Cluster  0 : [    29 121988]
# Cluster  0 : [   25 96428]
# Cluster  0 : [   19 92118]
# Cluster  0 : [    18 172864]
# Cluster  0 : [    28 116839]
# Cluster  0 : [  42 2935]
# Cluster  0 : [   23 52005]
# Cluster  0 : [   31 33867]
# Cluster  0 : [   45 40542]
# Cluster  0 : [    37 145773]
# Cluster  0 : [   22 70990]
# Cluster  0 : [ 26 493]
# Cluster  0 : [   40 23713]
# Cluster  0 : [   34 24659]
# Cluster  0 : [    19 156791]
# Cluster  0 : [    33 137599]
# Cluster  0 : [   29 99422]
# Cluster  0 : [   30 47866]
# Cluster  0 : [   18 16671]
# Cluster  0 : [   25 26363]
# Cluster  0 : [   21 82921]
# Cluster  0 : [    27 166930]
# Cluster  0 : [   17 14542]
# Cluster  0 : [    39 123796]
# Cluster  0 : [   22 41979]
# Cluster  0 : [   27 90337]
# Cluster  0 : [    32 166397]
# Cluster  0 : [   22 79217]
# Cluster  0 : [    19 124674]
# Cluster  0 : [   20 87629]
# Cluster  0 : [    33 131768]
# Cluster  0 : [   22 62423]
# Cluster  0 : [    40 151300]
# Cluster  0 : [   31 28812]
# Cluster  0 : [    27 181770]
# Cluster  0 : [   32 76919]
# Cluster  0 : [   38 84911]
# Cluster  0 : [ 60 414]
# Cluster  0 : [   19 78243]
# Cluster  0 : [   16 54141]
# Cluster  0 : [   24 48008]
# Cluster  0 : [   33 16667]
# Cluster  0 : [   24 48476]
# Cluster  0 : [  36 6053]
# Cluster  0 : [   41 63119]
# Cluster  0 : [   27 14023]
# Cluster  0 : [   24 67506]
# Cluster  0 : [    38 125242]
# Cluster  0 : [    32 105652]
# Cluster  0 : [    27 105529]
# Cluster  0 : [   22 29206]
# Cluster  0 : [    32 168318]
# Cluster  0 : [    32 171623]
# Cluster  0 : [    38 103891]
# Cluster  0 : [   25 48925]
# Cluster  0 : [    24 165823]
# Cluster  0 : [    23 104055]
# Cluster  0 : [   21 67360]
# Cluster  0 : [    22 163993]
# Cluster  0 : [   21 52607]
# Cluster  0 : [    25 153958]
# Cluster  0 : [    53 133314]
# Cluster  0 : [   25 76442]
# Cluster  0 : [    21 160257]
# Cluster  0 : [    43 162734]
# Cluster  0 : [    24 173553]
# Cluster  0 : [   39 63345]
# Cluster  0 : [   18 73223]
# Cluster  0 : [    20 143756]
# Cluster  0 : [   26 12354]
# Cluster  0 : [    18 121189]
# Cluster  0 : [    40 101629]
# Cluster  0 : [   20 43294]
# Cluster  0 : [    19 172305]
# Cluster  0 : [   38 24182]
# Cluster  0 : [    25 146980]
# Cluster  0 : [   43 56232]
# Cluster  0 : [   25 50875]
# Cluster  0 : [   41 59116]
# Cluster  0 : [    33 150179]
# Cluster  0 : [   29 57213]
# Cluster  0 : [    24 129287]
# Cluster  0 : [   33 63004]
# Cluster  0 : [    26 117288]
# Cluster  0 : [   35 44972]
# Cluster  0 : [   30 16638]
# Cluster  0 : [   20 41165]
# Cluster  0 : [   25 17456]
# Cluster  0 : [   50 70054]
# Cluster  0 : [   33 13147]
# Cluster  0 : [    24 161396]
# Cluster  0 : [   27 45408]
# Cluster  0 : [    30 111762]
# Cluster  0 : [   40 33173]
# Cluster  0 : [    22 177482]
# Cluster  0 : [   44 21479]
# Cluster  0 : [    47 101066]
# Cluster  0 : [   19 39786]
# Cluster  0 : [   33 44608]
# Cluster  0 : [   18 59633]
# Cluster  0 : [    24 148490]
# Cluster  0 : [  24 8502]
# Cluster  0 : [    50 145755]
# Cluster  0 : [    36 113775]
# Cluster  0 : [    27 181477]
# Cluster  0 : [    29 177418]
# Cluster  0 : [    41 131914]
# Cluster  0 : [ 18 969]
# Cluster  0 : [   32 85211]
# Cluster  0 : [   29 55994]
# Cluster  0 : [   30 82465]
# Cluster  0 : [    22 126740]
# Cluster  0 : [   33 29285]
# Cluster  0 : [    30 156882]
# Cluster  0 : [    36 106632]
# Cluster  0 : [    24 173638]
# Cluster  0 : [    38 181972]
# Cluster  0 : [   19 39226]
# Cluster  0 : [  37 9887]
# Cluster  0 : [   23 70962]
# Cluster  0 : [    17 158418]
# Cluster  0 : [   39 51261]
# Cluster  0 : [   19 80969]
# Cluster  0 : [   33 24627]
# Cluster  0 : [    37 147562]
# Cluster  0 : [   30 95762]
# Cluster  0 : [    30 158829]
# Cluster  0 : [   32 33681]
# Cluster  0 : [   22 27067]
# Cluster  0 : [   33 46841]
# Cluster  0 : [    30 183296]
# Cluster  0 : [    23 154258]
# Cluster  0 : [   43 94739]
# Cluster  0 : [   53 96426]
# Cluster  0 : [   24 94600]
# Cluster  0 : [    25 105023]
# Cluster  0 : [    21 110079]
# Cluster  0 : [    26 120492]
# Cluster  0 : [    39 124656]
# Cluster  0 : [    50 175037]
# Cluster  0 : [   18 77520]
# Cluster  0 : [    47 137021]
# Cluster  0 : [    21 123858]
# Cluster  0 : [   26 12769]
# Cluster  0 : [    19 141460]
# Cluster  0 : [    34 171418]
# Cluster  0 : [   24 52645]
# Cluster  0 : [    46 158379]
# Cluster  0 : [   27 74123]
# Cluster  0 : [   34 61940]
# Cluster  0 : [   50 84072]
# Cluster  0 : [    19 136736]
# Cluster  0 : [    53 147864]
# Cluster  0 : [   27 47080]
# Cluster  0 : [    30 177985]
# Cluster  0 : [    24 121531]
# Cluster  0 : [   33 67262]
# Cluster  0 : [   29 14830]
# Cluster  0 : [   34 25366]
# Cluster  0 : [    39 112882]
# Cluster  0 : [   26 17738]
# Cluster  0 : [   44 19672]
# Cluster  0 : [    37 124246]
# Cluster  0 : [    18 134422]
# Cluster  0 : [   21 15915]
# Cluster  0 : [    23 142046]
# Cluster  0 : [   26 95640]
# Cluster  0 : [    27 179461]
# Cluster  0 : [   31 45581]
# Cluster  0 : [    34 104362]
# Cluster  0 : [   56 93647]
# Cluster  0 : [   27 56183]
# Cluster  0 : [    24 167273]
# Cluster  0 : [    31 177709]
# Cluster  0 : [    25 140276]
# Cluster  0 : [    27 138097]
# Cluster  0 : [   38 34552]
# Cluster  0 : [    35 182165]
# Cluster  0 : [   24 89162]
# Cluster  0 : [   49 47703]
# Cluster  0 : [   28 46485]
# Cluster  0 : [   49 28236]
# Cluster  0 : [    27 144389]
# Cluster  0 : [    23 183517]
# Cluster  0 : [   32 25181]
# Cluster  0 : [   25 97195]
# Cluster  0 : [    20 173482]
# Cluster  0 : [    30 158300]
# Cluster  0 : [   55 92805]
# Cluster  0 : [    36 176848]
# Cluster  0 : [    26 118182]
# Cluster  0 : [   18 31127]
# Cluster  0 : [    50 164682]
# Cluster  0 : [   24 84854]
# Cluster  0 : [    36 114054]
# Cluster  0 : [    25 168604]
# Cluster  0 : [    21 154236]
# Cluster  0 : [   50 36658]
# Cluster  0 : [   30 27350]
# Cluster  0 : [   45 79367]
# Cluster  0 : [    35 130541]
# Cluster  0 : [   28 17546]
# Cluster  0 : [   47 83313]
# Cluster  0 : [    36 127769]
# Cluster  0 : [    37 123566]
# Cluster  0 : [    23 179845]
# Cluster  0 : [    29 147547]
# Cluster  0 : [  22 3138]
# Cluster  0 : [    25 114040]
# Cluster  0 : [   20 77954]
# Cluster  0 : [   49 99281]
# Cluster  0 : [    26 149730]
# Cluster  0 : [   34 45228]
# Cluster  0 : [    19 130792]
# Cluster  0 : [   24 89888]
# Cluster  0 : [    45 156112]
# Cluster  0 : [    30 158686]
# Cluster  0 : [    23 107620]
# Cluster  0 : [    30 177710]
# Cluster  0 : [    26 163071]
# Cluster  0 : [   19 33671]
# Cluster  0 : [    28 127897]
# Cluster  0 : [    23 152570]
# Cluster  0 : [   23 52192]
# Cluster  0 : [    37 130994]
# Cluster  0 : [   35 27416]
# Cluster  0 : [    19 116508]
# Cluster  0 : [    62 164131]
# Cluster  0 : [   29 19020]
# Cluster  0 : [    16 157058]
# Cluster  0 : [    21 167589]
# Cluster  0 : [    23 143509]
# Cluster  0 : [   29 10630]
# Cluster  0 : [   28 30062]
# Cluster  0 : [    22 102954]
# Cluster  0 : [   28 51357]
# Cluster  0 : [   39 20232]
# Cluster  0 : [   19 26761]
# Cluster  0 : [   38 76693]
# Cluster  0 : [    46 130991]
# Cluster  0 : [    26 154075]
# Cluster  0 : [    20 159010]
# Cluster  0 : [    51 174836]
# Cluster  0 : [    22 156265]
# Cluster  0 : [    27 168994]
# Cluster  0 : [    24 158868]
# Cluster  0 : [  57 7073]
# Cluster  0 : [   23 43565]
# Cluster  0 : [  25 9833]
# Cluster  0 : [    31 104908]
# Cluster  0 : [    18 169802]
# Cluster  0 : [   28 95623]
# Cluster  0 : [    25 172147]
# Cluster  0 : [   33 79458]
# Cluster  0 : [  19 9988]
# Cluster  0 : [    18 131318]
# Cluster  0 : [   25 88546]
# Cluster  0 : [   39 70131]
# Cluster  0 : [   22 25149]
# Cluster  0 : [    33 151804]
# Cluster  0 : [  22 7267]
# Cluster  0 : [    46 129125]
# Cluster  0 : [   30 54119]
# Cluster  0 : [   33 66285]
# Cluster  0 : [   52 73878]
# Cluster  0 : [    21 181340]
# Cluster  0 : [    52 180685]
# Cluster  0 : [    32 141500]
# Cluster  0 : [   22 77574]
# Cluster  0 : [   22 91604]
# Cluster  0 : [    26 126603]
# Cluster  0 : [    29 173279]
# Cluster  0 : [    18 152474]
# Cluster  0 : [    20 110257]
# Cluster  0 : [   22 36411]
# Cluster  0 : [   35 94621]
# Cluster  0 : [    23 111423]
# Cluster  0 : [   22 85556]
# Cluster  0 : [   24 21847]
# Cluster  0 : [   28 18207]
# Cluster  0 : [   31 48165]
# Cluster  0 : [    27 101340]
# Cluster  0 : [   27 18963]
# Cluster  0 : [   36 76558]
# Cluster  0 : [   26 46201]
# Cluster  0 : [   49 17088]
# Cluster  0 : [    23 182237]
# Cluster  0 : [   38 96312]
# Cluster  0 : [   39 53159]
# Cluster  0 : [    27 142492]
# Cluster  0 : [   24 64365]
# Cluster  0 : [   20 61414]
# Cluster  0 : [    27 169072]
# Cluster  0 : [    27 100420]
# Cluster  0 : [    28 176614]
# Cluster  0 : [   31 47750]
# Cluster  0 : [    32 132937]
# Cluster  0 : [    26 156122]
# Cluster  0 : [   34 15463]
# Cluster  0 : [    19 163741]
# Cluster  0 : [    28 168722]
# Cluster  0 : [    22 112186]
# Cluster  0 : [    33 171855]
# Cluster  0 : [   26 16121]
# Cluster  0 : [   34 61272]
# Cluster  0 : [   41 24299]
# Cluster  0 : [   20 76298]
# Cluster  0 : [   35 42293]
# Cluster  0 : [    40 130201]
# Cluster  0 : [   36 28458]
# Cluster  0 : [   29 68703]
# Cluster  0 : [   30 33061]
# Cluster  0 : [   40 31644]
# Cluster  0 : [    24 144420]
# Cluster  0 : [   47 54151]
# Cluster  0 : [    56 130137]
# Cluster  0 : [    19 153126]
# Cluster  0 : [   24 64757]
# Cluster  0 : [    41 161010]
# Cluster  0 : [   34 25322]
# Cluster  0 : [    46 150241]
# Cluster  0 : [   20 45635]
# Cluster  0 : [   20 53859]
# Cluster  0 : [    21 100370]
# Cluster  0 : [    28 130910]
# Cluster  0 : [   21 44843]
# Cluster  0 : [    21 150041]
# Cluster  0 : [    26 181603]
# Cluster  0 : [   27 91628]
# Cluster  0 : [    30 140414]
# Cluster  0 : [   44 96221]
# Cluster  0 : [   39 86140]
# Cluster  0 : [   21 89339]
# Cluster  0 : [   26 66073]
# Cluster  0 : [    29 175616]
# Cluster  0 : [   30 91696]
# Cluster  0 : [   26 80311]
# Cluster  0 : [    20 131736]
# Cluster  0 : [   32 85940]
# Cluster  0 : [   30 13945]
# Cluster  0 : [   29 72716]
# Cluster  0 : [   30 74637]
# Cluster  0 : [   34 74466]
# Cluster  0 : [   72 61146]
# Cluster  0 : [   35 80320]
# Cluster  0 : [   34 59799]
# Cluster  0 : [  19 8951]
# Cluster  0 : [  27 1433]
# Cluster  0 : [    30 120574]
# Cluster  0 : [    31 170093]
# Cluster  0 : [   23 58661]
# Cluster  0 : [    38 123014]
# Cluster  0 : [   32 81329]
# Cluster  0 : [   20 97411]
# Cluster  0 : [   39 49399]
# Cluster  0 : [    29 168541]
# Cluster  0 : [   25 52020]
# Cluster  0 : [    47 180515]
# Cluster  0 : [   40 92016]
# Cluster  0 : [   17 70486]
# Cluster  0 : [   27 38025]
# Cluster  0 : [    28 105221]
# Cluster  0 : [    24 102805]
# Cluster  0 : [    30 178875]
# Cluster  0 : [   20 64109]
# Cluster  0 : [    24 138982]
# Cluster  0 : [   39 32835]
# Cluster  0 : [   23 35578]
# Cluster  0 : [    21 185240]
# Cluster  0 : [   25 45279]
# Cluster  0 : [    21 169862]
# Cluster  0 : [    36 113190]
# Cluster  0 : [    36 182388]
# Cluster  0 : [   20 32483]
# Cluster  0 : [   44 92774]
# Cluster  0 : [    27 159917]
# Cluster  0 : [    21 112980]
# Cluster  0 : [    21 137666]
# Cluster  0 : [    24 100092]
# Cluster  0 : [   38 76209]
# Cluster  0 : [   58 47594]
# Cluster  0 : [    21 105784]
# Cluster  0 : [    24 148343]
# Cluster  0 : [   25 18103]
# Cluster  0 : [   34 50570]
# Cluster  0 : [   36 70825]
# Cluster  0 : [   32 89061]
# Cluster  0 : [   22 97395]
# Cluster  0 : [    45 160986]
# Cluster  0 : [    37 153220]
# Cluster  0 : [    26 168708]
# Cluster  0 : [   32 98731]
# Cluster  0 : [   54 11562]
# Cluster  0 : [   41 62601]
# Cluster  0 : [    30 176101]
# Cluster  0 : [    22 142981]
# Cluster  0 : [    26 111725]
# Cluster  0 : [   32 23598]
# Cluster  0 : [   22 73157]
# Cluster  0 : [    21 171585]
# Cluster  0 : [   18 98422]
# Cluster  0 : [   38 84317]
# Cluster  0 : [   42 47474]
# Cluster  0 : [    28 105517]
# Cluster  0 : [   26 36580]
# Cluster  0 : [    30 179170]
# Cluster  0 : [    27 132076]
# Cluster  0 : [   20 79638]
# Cluster  0 : [   32 60682]
# Cluster  0 : [   32 35459]
# Cluster  0 : [    18 172644]
# Cluster  0 : [   22 47011]
# Cluster  0 : [    25 172700]
# Cluster  0 : [   26 61992]
# Cluster  0 : [   34 97234]
# Cluster  0 : [    23 158106]
# Cluster  0 : [   28 78835]
# Cluster  0 : [    21 128946]
# Cluster  0 : [    34 134793]
# Cluster  0 : [   35 24521]
# Cluster  0 : [   28 60863]
# Cluster  0 : [    30 183972]
# Cluster  0 : [    29 103701]
# Cluster  0 : [   17 83718]
# Cluster  0 : [    28 160134]
# Cluster  0 : [   26 86390]
# Cluster  0 : [  24 5899]
# Cluster  0 : [    43 118326]
# Cluster  0 : [    22 149527]
# Cluster  0 : [   28 89212]
# Cluster  0 : [   46 41052]
# Cluster  0 : [   30 85685]
# Cluster  0 : [   28 17789]
# Cluster  0 : [    52 167748]
# Cluster  0 : [   33 22651]
# Cluster  0 : [   20 53820]
# Cluster  0 : [    32 120363]
# Cluster  0 : [    34 121143]
# Cluster  0 : [   29 61864]
# Cluster  0 : [    34 183924]
# Cluster  0 : [    50 100641]
# Cluster  0 : [   28 25704]
# Cluster  0 : [    24 130923]
# Cluster  0 : [   46 62851]
# Cluster  0 : [    41 104915]
# Cluster  0 : [   24 50731]
# Cluster  0 : [   25 91044]
# Cluster  0 : [   23 93884]
# Cluster  0 : [    21 183741]
# Cluster  0 : [   24 55401]
# Cluster  0 : [   29 33791]
# Cluster  0 : [   36 51267]
# Cluster  0 : [    32 105844]
# Cluster  0 : [    25 113842]
# Cluster  0 : [  28 1898]
# Cluster  0 : [    41 146252]
# Cluster  0 : [   33 12904]
# Cluster  0 : [   37 65112]
# Cluster  0 : [    28 123089]
# Cluster  0 : [    21 181295]
# Cluster  0 : [   31 72060]
# Cluster  0 : [   24 21805]
# Cluster  0 : [   45 14624]
# Cluster  0 : [    64 132860]
# Cluster  0 : [   56 88224]
# Cluster  0 : [    29 107915]
# Cluster  0 : [   25 92257]
# Cluster  0 : [   20 61700]
# Cluster  0 : [    33 173989]
# Cluster  0 : [    44 113020]
# Cluster  0 : [    41 120158]
# Cluster  0 : [   40 69010]
# Cluster  0 : [   20 77557]
# Cluster  0 : [    29 126189]
# Cluster  0 : [    49 151525]
# Cluster  0 : [    19 166516]
# Cluster  0 : [   25 37718]
# Cluster  0 : [   27 51418]
# Cluster  0 : [   32 27062]
# Cluster  0 : [   22 49644]
# Cluster  0 : [    56 164504]
# Cluster  0 : [   30 26937]
# Cluster  0 : [   36 39781]
# Cluster  0 : [    30 152953]
# Cluster  0 : [    27 142541]
# Cluster  0 : [   39 44722]
# Cluster  0 : [   20 34289]
# Cluster  0 : [   46 33450]
# Cluster  0 : [   51 12373]
# Cluster  0 : [    55 135368]
# Cluster  0 : [  36 4793]
# Cluster  0 : [    29 154632]
# Cluster  0 : [   21 34549]
# Cluster  0 : [   27 77723]
# Cluster  0 : [    20 159962]
# Cluster  0 : [  21 2190]
# Cluster  0 : [    21 179887]
# Cluster  0 : [    47 137381]
# Cluster  0 : [    27 108171]
# Cluster  0 : [   26 67207]
# Cluster  0 : [   46 83061]
# Cluster  0 : [    31 177948]
# Cluster  0 : [    44 183625]
# Cluster  0 : [    64 181207]
# Cluster  0 : [   21 31419]
# Cluster  0 : [    29 174669]
# Cluster  0 : [    26 112742]
# Cluster  0 : [  25 8434]
# Cluster  0 : [    37 162550]
# Cluster  0 : [    53 130914]
# Cluster  0 : [    29 178402]
# Cluster  0 : [   34 27327]
# Cluster  0 : [   23 57877]
# Cluster  0 : [    22 141239]
# Cluster  0 : [    43 153034]
# Cluster  0 : [    32 113181]
# Cluster  0 : [   21 90779]
# Cluster  0 : [    19 179395]
# Cluster  0 : [  26 2726]
# Cluster  0 : [   40 37105]
# Cluster  0 : [   23 80720]
# Cluster  0 : [   33 32235]
# Cluster  0 : [   25 63885]
# Cluster  0 : [    22 183566]
# Cluster  0 : [   24 49261]
# Cluster  0 : [   30 28987]
# Cluster  0 : [    34 167088]
# Cluster  0 : [    56 133935]
# Cluster  0 : [    42 161820]
# Cluster  0 : [    17 156722]
# Cluster  0 : [    35 149842]
# Cluster  0 : [   33 99861]
# Cluster  0 : [    28 136589]
# Cluster  0 : [    27 159789]
# Cluster  0 : [    23 134772]
# Cluster  0 : [  24 4965]
# Cluster  0 : [   28 97175]
# Cluster  0 : [    22 120043]
# Cluster  0 : [   31 62427]
# Cluster  0 : [    25 154982]
# Cluster  0 : [   37 91300]
# Cluster  0 : [   28 97827]
# Cluster  0 : [    35 143988]
# Cluster  0 : [   33 95173]
# Cluster  0 : [    53 108197]
# Cluster  0 : [   20 93662]
# Cluster  0 : [    47 183290]
# Cluster  0 : [    21 149060]
# Cluster  0 : [   19 27963]
# Cluster  0 : [    25 134122]
# Cluster  0 : [   20 33523]
# Cluster  0 : [   30 32075]
# Cluster  0 : [  39 7455]
# Cluster  0 : [   21 74948]
# Cluster  0 : [    29 180384]
# Cluster  0 : [   43 50381]
# Cluster  0 : [   22 65166]
# Cluster  0 : [   35 99242]
# Cluster  0 : [   37 53580]
# Cluster  0 : [    26 138795]
# Cluster  0 : [   26 28090]
# Cluster  0 : [    53 154455]
# Cluster  0 : [    33 111291]
# Cluster  0 : [    54 152722]
# Cluster  0 : [    29 162647]
# Cluster  0 : [    23 100893]
# Cluster  0 : [    26 142670]
# Cluster  0 : [    24 148361]
# Cluster  0 : [    42 171589]
# Cluster  0 : [    43 105931]
# Cluster  0 : [    24 178437]
# Cluster  0 : [    29 159215]
# Cluster  0 : [   18 17403]
# Cluster  0 : [   28 84766]
# Cluster  0 : [    23 185802]
# Cluster  0 : [    21 137883]
# Cluster  0 : [   20 82085]
# Cluster  0 : [   20 57401]
# Cluster  0 : [   32 51579]
# Cluster  0 : [   23 79759]
# Cluster  0 : [   19 42284]
# Cluster  0 : [   33 41901]
# Cluster  0 : [   26 89225]
# Cluster  0 : [   16 25268]
# Cluster  0 : [   46 41083]
# Cluster  0 : [    30 129299]
# Cluster  0 : [   29 46034]
# Cluster  0 : [   35 57183]
# Cluster  0 : [   28 37449]
# Cluster  0 : [   21 88553]
# Cluster  0 : [  35 6730]
# Cluster  0 : [   22 43606]
# Cluster  0 : [    23 111544]
# Cluster  0 : [   33 40054]
# Cluster  0 : [   30 50196]
# Cluster  0 : [   31 90229]
# Cluster  0 : [    41 168121]
# Cluster  0 : [   32 60527]
# Cluster  0 : [    32 118781]
# Cluster  0 : [   34 33119]
# Cluster  0 : [   22 94262]
# Cluster  0 : [    22 120188]
# Cluster  0 : [   47 38036]
# Cluster  0 : [    19 162298]
# Cluster  0 : [    41 166725]
# Cluster  0 : [   31 47685]
# Cluster  0 : [    24 119309]
# Cluster  0 : [   47 22871]
# Cluster  0 : [   34 64155]
# Cluster  0 : [   26 13493]
# Cluster  0 : [   37 38630]
# Cluster  0 : [    21 106305]
# Cluster  0 : [   25 15787]
# Cluster  0 : [   32 96344]
# Cluster  0 : [   49 93187]
# Cluster  0 : [ 20 621]
# Cluster  0 : [   30 63205]
# Cluster  0 : [    31 185684]
# Cluster  0 : [    23 161377]
# Cluster  0 : [   34 23825]
# Cluster  0 : [    27 173479]
# Cluster  0 : [   24 85223]
# Cluster  0 : [  32 4750]
# Cluster  0 : [   23 92919]
# Cluster  0 : [   28 60798]
# Cluster  0 : [   31 97621]
# Cluster  0 : [    19 113581]
# Cluster  0 : [    25 148548]
# Cluster  0 : [   45 18644]
# Cluster  0 : [   33 40604]
# Cluster  0 : [    28 180674]
# Cluster  0 : [    29 180734]
# Cluster  0 : [   41 14886]
# Cluster  0 : [    49 158937]
# Cluster  0 : [    18 173185]
# Cluster  0 : [   21 16144]
# Cluster  0 : [   64 52118]
# Cluster  0 : [   47 75489]
# Cluster  0 : [   30 57408]
# Cluster  0 : [   18 56940]
# Cluster  0 : [    39 129812]
# Cluster  0 : [   26 73191]
# Cluster  0 : [   34 67111]
# Cluster  0 : [   21 64120]
# Cluster  0 : [    29 140898]
# Cluster  0 : [    23 166936]
# Cluster  0 : [    23 151379]
# Cluster  0 : [   20 16454]
# Cluster  0 : [    34 103951]
# Cluster  0 : [    37 113832]
# Cluster  0 : [   25 70941]
# Cluster  0 : [   18 27501]
# Cluster  0 : [   19 31404]
# Cluster  0 : [   17 34477]
# Cluster  0 : [   43 81754]
# Cluster  0 : [    18 119910]
# Cluster  0 : [    21 144005]
# Cluster  0 : [    21 121659]
# Cluster  0 : [    31 138382]
# Cluster  0 : [    23 130231]
# Cluster  0 : [    19 164709]
# Cluster  0 : [   20 32139]
# Cluster  0 : [   28 39215]
# Cluster  0 : [   58 48624]
# Cluster  0 : [    21 120091]
# Cluster  0 : [   24 27030]
# Cluster  0 : [   22 77521]
# Cluster  0 : [   20 52386]
# Cluster  0 : [   37 70877]
# Cluster  0 : [   19 13061]
# Cluster  0 : [    28 177195]
# Cluster  0 : [    31 168383]
# Cluster  0 : [   48 17697]
# Cluster  0 : [    57 174156]
# Cluster  0 : [    25 177942]
# Cluster  0 : [    40 181173]
# Cluster  0 : [   32 29042]
# Cluster  0 : [   33 58403]
# Cluster  0 : [    41 171896]
# Cluster  0 : [   27 78514]
# Cluster  0 : [   18 37462]
# Cluster  0 : [    23 106109]
# Cluster  0 : [    18 177483]
# Cluster  0 : [    30 165111]
# Cluster  0 : [    36 167477]
# Cluster  0 : [    27 112279]
# Cluster  0 : [   21 50881]
# Cluster  0 : [   30 85900]
# Cluster  0 : [    27 119292]
# Cluster  0 : [   41 85076]
# Cluster  0 : [   27 48799]
# Cluster  0 : [    40 103642]
# Cluster  0 : [   26 29677]
# Cluster  0 : [   42 57738]
# Cluster  0 : [   34 70663]
# Cluster  0 : [    40 183158]
# Cluster  0 : [   42 28030]
# Cluster  0 : [    21 125581]
# Cluster  0 : [    33 122409]
# Cluster  0 : [    17 111121]
# Cluster  0 : [   22 81307]
# Cluster  0 : [    22 174166]
# Cluster  0 : [    30 134105]
# Cluster  0 : [    36 155397]
# Cluster  0 : [    39 144109]
# Cluster  0 : [    25 129682]
# Cluster  0 : [    41 165814]
# Cluster  0 : [    43 125517]
# Cluster  0 : [   30 80101]
# Cluster  0 : [    42 139686]
# Cluster  0 : [   39 34427]
# Cluster  0 : [   29 82476]
# Cluster  0 : [   28 78460]
# Cluster  0 : [   21 90785]
# Cluster  0 : [   31 20148]
# Cluster  0 : [   31 84341]
# Cluster  0 : [    22 166217]
# Cluster  0 : [   29 10468]
# Cluster  0 : [   52 18848]
# Cluster  0 : [   39 85788]
# Cluster  0 : [   18 16741]
# Cluster  0 : [   33 29789]
# Cluster  0 : [ 28 992]
# Cluster  0 : [   28 60726]
# Cluster  0 : [    30 111846]
# Cluster  0 : [    44 117703]
# Cluster  0 : [    27 166243]
# Cluster  0 : [    26 168756]
# Cluster  0 : [    28 136906]
# Cluster  0 : [    26 119704]
# Cluster  0 : [    44 165609]
# Cluster  0 : [    32 150234]
# Cluster  0 : [    35 136395]
# Cluster  0 : [   26 21388]
# Cluster  0 : [   40 29250]
# Cluster  0 : [    25 124140]
# Cluster  0 : [    18 147543]
# Cluster  0 : [   26 82469]
# Cluster  0 : [   53 96520]
# Cluster  0 : [ 22 884]
# Cluster  0 : [  20 8596]
# Cluster  0 : [   18 30100]
# Cluster  0 : [    21 160831]
# Cluster  0 : [   34 83916]
# Cluster  0 : [    25 131282]
# Cluster  0 : [   24 68681]
# Cluster  0 : [   62 33600]
# Cluster  0 : [   19 78372]
# Cluster  0 : [   27 90418]
# Cluster  0 : [    20 120625]
# Cluster  0 : [    23 143565]
# Cluster  0 : [   36 60242]
# Cluster  0 : [    37 159701]
# Cluster  0 : [    37 174318]
# Cluster  0 : [    36 157713]
# Cluster  0 : [    44 116355]
# Cluster  0 : [    26 164462]
# Cluster  0 : [    53 153705]
# Cluster  0 : [   27 77029]
# Cluster  0 : [    28 122443]
# Cluster  0 : [    43 117302]
# Cluster  0 : [    25 175437]
# Cluster  0 : [    61 133429]
# Cluster  0 : [   17 25698]
# Cluster  0 : [    36 155287]
# Cluster  0 : [    72 152523]
# Cluster  0 : [    33 163655]
# Cluster  0 : [   57 24514]
# Cluster  0 : [   20 71359]
# Cluster  0 : [   38 52558]
# Cluster  0 : [   30 22195]
# Cluster  0 : [   22 11728]
# Cluster  0 : [   33 85415]
# Cluster  0 : [   28 98729]
# Cluster  0 : [   37 91254]
# Cluster  0 : [   22 80624]
# Cluster  0 : [   35 78424]
# Cluster  0 : [    42 120062]
# Cluster  0 : [    36 180164]
# Cluster  0 : [    25 108103]
# Cluster  0 : [  30 8657]
# Cluster  0 : [   28 95567]
# Cluster  0 : [    18 120631]
# Cluster  0 : [    35 125373]
# Cluster  0 : [    23 171534]
# Cluster  0 : [    20 115300]
# Cluster  0 : [    47 119905]
# Cluster  0 : [   20 78960]
# Cluster  0 : [   20 48793]
# Cluster  0 : [    43 136288]
# Cluster  0 : [   21 45227]
# Cluster  0 : [    43 133055]
# Cluster  0 : [    24 172922]
# Cluster  0 : [   31 24338]
# Cluster  0 : [    49 111626]
# Cluster  0 : [   40 46540]
# Cluster  0 : [    24 156195]
# Cluster  0 : [   32 86932]
# Cluster  0 : [   22 40591]
# Cluster  0 : [   25 92027]
# Cluster  0 : [   26 12712]
# Cluster  0 : [   28 36303]
# Cluster  0 : [   19 43681]
# Cluster  0 : [  22 5992]
# Cluster  0 : [   31 19173]
# Cluster  0 : [   33 68963]
# Cluster  0 : [    23 122475]
# Cluster  0 : [   64 19290]
# Cluster  0 : [    71 111630]
# Cluster  0 : [   40 45543]
# Cluster  0 : [    27 183347]
# Cluster  0 : [   42 26312]
# Cluster  0 : [    29 170728]
# Cluster  0 : [   38 28460]
# Cluster  0 : [   31 84727]
# Cluster  0 : [   26 19123]
# Cluster  0 : [    48 168814]
# Cluster  0 : [    28 167658]
# Cluster  0 : [    23 165889]
# Cluster  0 : [  35 5958]
# Cluster  0 : [  24 1616]
# Cluster  0 : [    21 117978]
# Cluster  0 : [   35 15690]
# Cluster  0 : [    35 157879]
# Cluster  0 : [    28 132666]
# Cluster  0 : [  21 5685]
# Cluster  0 : [ 32 541]
# Cluster  0 : [    21 170179]
# Cluster  0 : [   20 69541]
# Cluster  0 : [   33 86387]
# Cluster  0 : [   29 17544]
# Cluster  0 : [    38 126617]
# Cluster  0 : [  32 9980]
# Cluster  0 : [    25 153990]
# Cluster  0 : [   31 29047]
# Cluster  0 : [    38 160628]
# Cluster  0 : [   21 19844]
# Cluster  0 : [   37 85671]
# Cluster  0 : [    19 171173]
# Cluster  0 : [    25 105523]
# Cluster  0 : [   31 28801]
# Cluster  0 : [    42 121074]
# Cluster  0 : [    20 120211]
# Cluster  0 : [   68 22739]
# Cluster  0 : [   32 91903]
# Cluster  0 : [   20 87386]
# Cluster  0 : [   39 93115]
# Cluster  0 : [   22 23507]
# Cluster  0 : [   24 48048]
# Cluster  0 : [   27 21717]
# Cluster  0 : [   42 82242]
# Cluster  0 : [   30 37145]
# Cluster  0 : [    28 108079]
# Cluster  0 : [   32 26896]
# Cluster  0 : [   37 50364]
# Cluster  0 : [   36 76223]
# Cluster  0 : [    35 118128]
# Cluster  0 : [   44 90696]
# Cluster  0 : [   22 41999]
# Cluster  0 : [   42 24155]
# Cluster  0 : [   26 85433]
# Cluster  0 : [   35 11866]
# Cluster  0 : [   21 26669]
# Cluster  0 : [   20 63729]
# Cluster  0 : [  40 1269]
# Cluster  0 : [   26 81929]
# Cluster  0 : [    37 184097]
# Cluster  0 : [   20 10051]
# Cluster  0 : [    32 153269]
# Cluster  0 : [  44 9061]
# Cluster  0 : [    27 185041]
# Cluster  0 : [    29 101798]
# Cluster  0 : [   35 67719]
# Cluster  0 : [    27 151847]
# Cluster  0 : [   21 41312]
# Cluster  0 : [   21 44084]
# Cluster  0 : [    22 172997]
# Cluster  0 : [   26 22376]
# Cluster  0 : [    49 119840]
# Cluster  0 : [    21 115436]
# Cluster  0 : [    18 125890]
# Cluster  0 : [   19 84676]
# Cluster  0 : [   23 13481]
# Cluster  0 : [    47 104082]
# Cluster  0 : [    40 170692]
# Cluster  0 : [    22 116845]
# Cluster  0 : [    22 148062]
# Cluster  0 : [    23 131108]
# Cluster  0 : [   28 37432]
# Cluster  0 : [   37 62325]
# Cluster  0 : [    31 161283]
# Cluster  0 : [   23 73738]
# Cluster  0 : [    28 184442]
# Cluster  0 : [   42 46133]
# Cluster  0 : [    24 141443]
# Cluster  0 : [    29 100355]
# Cluster  0 : [    31 134014]
# Cluster  0 : [   53 88503]
# Cluster  0 : [    46 121352]
# Cluster  0 : [    24 125085]
# Cluster  0 : [    21 106824]
# Cluster  0 : [   29 19962]
# Cluster  0 : [   34 27065]
# Cluster  0 : [    22 153192]
# Cluster  0 : [   64 40715]
# Cluster  0 : [    31 164630]
# Cluster  0 : [   39 28173]
# Cluster  0 : [   21 87319]
# Cluster  0 : [   27 26428]
# Cluster  0 : [    20 171525]
# Cluster  0 : [  45 6029]
# Cluster  0 : [    24 110592]
# Cluster  0 : [    39 144569]
# Cluster  0 : [    17 135051]
# Cluster  0 : [   29 42818]
# Cluster  0 : [   38 82369]
# Cluster  0 : [   20 61902]
# Cluster  0 : [    27 178098]
# Cluster  0 : [   33 99656]
# Cluster  0 : [   37 70224]
# Cluster  0 : [   18 18349]
# Cluster  0 : [    31 166421]
# Cluster  0 : [    23 151701]
# Cluster  0 : [   29 87548]
# Cluster  0 : [    28 125561]
# Cluster  0 : [    20 143133]
# Cluster  0 : [   22 27020]
# Cluster  0 : [  19 8396]
# Cluster  0 : [    38 136150]
# Cluster  0 : [    30 101058]
# Cluster  0 : [    21 139684]
# Cluster  0 : [    30 176406]
# Cluster  0 : [ 25 620]
# Cluster  0 : [    48 175213]
# Cluster  0 : [   26 36982]
# Cluster  0 : [    31 166547]
# Cluster  0 : [   25 39941]
# Cluster  0 : [   27 74924]
# Cluster  0 : [    31 115225]
# Cluster  0 : [    29 150215]
# Cluster  0 : [   18 35599]
# Cluster  0 : [    20 137109]
# Cluster  0 : [    19 149619]
# Cluster  0 : [   19 23278]
# Cluster  0 : [    22 132362]
# Cluster  0 : [    23 148776]
# Cluster  0 : [    24 139257]
# Cluster  0 : [    35 160679]
# Cluster  0 : [    29 160267]
# Cluster  0 : [   23 28271]
# Cluster  0 : [   40 72674]
# Cluster  0 : [    28 130511]
# Cluster  0 : [   24 87937]
# Cluster  0 : [   41 26046]
# Cluster  0 : [   27 55297]
# Cluster  0 : [   17 45122]
# Cluster  0 : [   20 80691]
# Cluster  0 : [  44 6294]
# Cluster  0 : [    31 136105]
# Cluster  0 : [    39 109674]
# Cluster  0 : [   28 67036]
# Cluster  0 : [   43 74888]
# Cluster  0 : [   24 63578]
# Cluster  0 : [    21 109172]
# Cluster  0 : [   25 90322]
# Cluster  0 : [   29 21733]
# Cluster  0 : [   23 33571]
# Cluster  0 : [    32 150955]
# Cluster  0 : [    33 142302]
# Cluster  0 : [    39 114419]
# Cluster  0 : [   30 72236]
# Cluster  0 : [   25 96038]
# Cluster  0 : [   45 40345]
# Cluster  0 : [   33 63748]
# Cluster  0 : [    24 139923]
# Cluster  0 : [    46 111889]
# Cluster  0 : [   33 65011]
# Cluster  0 : [   23 30765]
# Cluster  0 : [   25 85818]
# Cluster  0 : [    25 160587]
# Cluster  0 : [   28 62356]
# Cluster  0 : [    21 176570]
# Cluster  0 : [   33 39788]
# Cluster  0 : [   33 86000]
# Cluster  0 : [    23 125979]
# Cluster  0 : [   38 56515]
# Cluster  0 : [   20 96468]
# Cluster  0 : [    68 123272]
# Cluster  0 : [   18 90693]
# Cluster  0 : [   27 90926]
# Cluster  0 : [    20 149014]
# Cluster  0 : [   25 90722]
# Cluster  0 : [   40 87660]
# Cluster  0 : [    27 159186]
# Cluster  0 : [   24 77324]
# Cluster  0 : [   30 75968]
# Cluster  0 : [    26 147481]
# Cluster  0 : [    28 158189]
# Cluster  0 : [    22 136140]
# Cluster  0 : [   45 62926]
# Cluster  0 : [   37 93340]
# Cluster  0 : [   25 39836]
# Cluster  0 : [   30 31951]
# Cluster  0 : [   39 53819]
# Cluster  0 : [   33 76959]
# Cluster  0 : [   22 31632]
# Cluster  0 : [   32 38270]
# Cluster  0 : [    32 154817]
# Cluster  0 : [   38 52720]
# Cluster  0 : [  55 9637]
# Cluster  0 : [    38 165836]
# Cluster  0 : [   47 75598]
# Cluster  0 : [    34 112673]
# Cluster  0 : [   22 54806]
# Cluster  0 : [    22 104834]
# Cluster  0 : [   34 84915]
# Cluster  0 : [   38 57565]
# Cluster  0 : [    29 138712]
# Cluster  0 : [   50 64801]
# Cluster  0 : [    34 109235]
# Cluster  0 : [   31 42434]
# Cluster  0 : [  34 6225]
# Cluster  0 : [    46 129069]
# Cluster  0 : [    23 159286]
# Cluster  0 : [    19 175806]
# Cluster  0 : [    27 122732]
# Cluster  0 : [   30 27343]
# Cluster  0 : [   37 81704]
# Cluster  0 : [    37 120639]
# Cluster  0 : [    24 184816]
# Cluster  0 : [   31 32422]
# Cluster  0 : [    20 125669]
# Cluster  0 : [    67 130284]
# Cluster  0 : [  41 8942]
# Cluster  0 : [   30 80947]
# Cluster  0 : [    41 103826]
# Cluster  0 : [  21 5261]
# Cluster  0 : [    23 183369]
# Cluster  0 : [    21 136648]
# Cluster  0 : [   21 11113]
# Cluster  0 : [    22 126000]
# Cluster  0 : [  31 8642]
# Cluster  0 : [   31 60591]
# Cluster  0 : [   40 12365]
# Cluster  0 : [    21 111943]
# Cluster  0 : [    43 142081]
# Cluster  0 : [   22 65430]
# Cluster  0 : [   25 33041]
# Cluster  0 : [    55 131600]
# Cluster  0 : [    35 152080]
# Cluster  0 : [    29 161284]
# Cluster  0 : [    49 142574]
# Cluster  0 : [    26 144459]
# Cluster  0 : [   21 78882]
# Cluster  0 : [   26 63452]
# Cluster  0 : [   22 84466]
# Cluster  0 : [    19 133996]
# Cluster  0 : [   49 22361]
# Cluster  0 : [    19 122992]
# Cluster  0 : [    25 101251]
# Cluster  0 : [    32 113211]
# Cluster  0 : [ 26 582]
# Cluster  0 : [   18 64642]
# Cluster  0 : [    34 126159]
# Cluster  0 : [   47 18322]
# Cluster  0 : [   29 23028]
# Cluster  0 : [   20 79108]
# Cluster  0 : [   25 12738]
# Cluster  0 : [   25 78950]
# Cluster  0 : [    29 125832]
# Cluster  0 : [    28 115027]
# Cluster  0 : [    22 107252]
# Cluster  0 : [    29 120134]
# Cluster  0 : [    18 108765]
# Cluster  0 : [    55 176927]
# Cluster  0 : [    53 112550]
# Cluster  0 : [   20 31608]
# Cluster  0 : [    48 174189]
# Cluster  0 : [   36 41955]
# Cluster  0 : [    20 129483]
# Cluster  0 : [    44 147348]
# Cluster  0 : [    35 137497]
# Cluster  0 : [   28 10191]
# Cluster  0 : [    33 131704]
# Cluster  0 : [    43 109025]
# Cluster  0 : [   36 60491]
# Cluster  0 : [    20 115097]
# Cluster  0 : [   31 33514]
# Cluster  0 : [    21 148768]
# Cluster  0 : [    43 165970]
# Cluster  0 : [   47 32571]
# Cluster  0 : [   24 22073]
# Cluster  0 : [    46 107487]
# Cluster  0 : [   30 21972]
# Cluster  0 : [  25 9822]
# Cluster  0 : [    22 111355]
# Cluster  0 : [  50 3640]
# Cluster  0 : [   32 38426]
# Cluster  0 : [  16 1692]
# Cluster  0 : [    38 144239]
# Cluster  0 : [    31 112704]
# Cluster  0 : [  28 9047]
# Cluster  0 : [   24 21666]
# Cluster  0 : [   38 96567]
# Cluster  0 : [   45 70846]
# Cluster  0 : [    24 160256]
# Cluster  0 : [   24 52010]
# Cluster  0 : [   37 73359]
# Cluster  0 : [    31 131558]
# Cluster  0 : [    26 102475]
# Cluster  0 : [    30 172615]
# Cluster  0 : [   43 56249]
# Cluster  0 : [    29 169126]
# Cluster  0 : [  37 6795]
# Cluster  0 : [   50 75313]
# Cluster  0 : [   27 79655]
# Cluster  0 : [    22 112733]
# Cluster  0 : [   29 22998]
# Cluster  0 : [   28 30979]
# Cluster  0 : [   32 74559]
# Cluster  0 : [    32 120253]
# Cluster  0 : [   32 65106]
# Cluster  0 : [    37 158841]
# Cluster  0 : [    50 173443]
# Cluster  0 : [   22 99573]
# Cluster  0 : [   27 89600]
# Cluster  0 : [    16 141566]
# Cluster  0 : [   28 33540]
# Cluster  0 : [    24 178729]
# Cluster  0 : [   36 14009]
# Cluster  0 : [   22 26851]
# Cluster  0 : [    58 135574]
# Cluster  0 : [    35 171750]
# Cluster  0 : [   22 69417]
# Cluster  0 : [    39 116555]
# Cluster  0 : [    23 180213]
# Cluster  0 : [   49 86176]
# Cluster  0 : [   21 62563]
# Cluster  0 : [    48 150879]
# Cluster  0 : [    33 124418]
# Cluster  0 : [    48 153259]
# Cluster  0 : [   27 94400]
# Cluster  0 : [   30 57581]
# Cluster  0 : [    27 168011]
# Cluster  0 : [   19 77153]
# Cluster  0 : [    31 114980]
# Cluster  0 : [    26 101804]
# Cluster  0 : [  35 3214]
# Cluster  0 : [    33 105978]
# Cluster  0 : [   30 74399]
# Cluster  0 : [   35 25138]
# Cluster  0 : [    22 122179]
# Cluster  0 : [    23 172396]
# Cluster  0 : [   24 12882]
# Cluster  0 : [    37 137082]
# Cluster  0 : [    46 161191]
# Cluster  0 : [ 21 490]
# Cluster  0 : [   74 82182]
# Cluster  0 : [   28 35441]
# Cluster  0 : [    39 146095]
# Cluster  0 : [  19 9242]
# Cluster  0 : [   26 41343]
# Cluster  0 : [   45 93070]
# Cluster  0 : [   39 10979]
# Cluster  0 : [    22 146031]
# Cluster  0 : [   24 62056]
# Cluster  0 : [   54 22670]
# Cluster  0 : [    31 130224]
# Cluster  0 : [   35 29145]
# Cluster  0 : [   20 57692]
# Cluster  0 : [   52 66890]
# Cluster  0 : [   34 79821]
# Cluster  0 : [    31 135147]
# Cluster  0 : [   19 57233]
# Cluster  0 : [   36 63963]
# Cluster  0 : [    19 107408]
# Cluster  0 : [    20 185780]
# Cluster  0 : [    28 172952]
# Cluster  0 : [   34 57599]
# Cluster  0 : [    18 131939]
# Cluster  0 : [    24 135724]
# Cluster  0 : [    38 103011]
# Cluster  0 : [   44 10377]
# Cluster  0 : [  19 6366]
# Cluster  0 : [    22 118522]
# Cluster  0 : [   39 85144]
# Cluster  0 : [   18 45119]
# Cluster  0 : [   24 44687]
# Cluster  0 : [    19 100766]
# Cluster  0 : [    29 162667]
# Cluster  0 : [   22 27104]
# Cluster  0 : [    25 177874]
# Cluster  0 : [   23 69030]
# Cluster  0 : [   32 34474]
# Cluster  0 : [    29 170059]
# Cluster  0 : [   23 95887]
# Cluster  0 : [   37 64061]
# Cluster  0 : [    25 175462]
# Cluster  0 : [    29 117348]
# Cluster  0 : [   66 10617]
# Cluster  0 : [    60 153933]
# Cluster  0 : [    31 143643]
# Cluster  0 : [  18 1744]
# Cluster  0 : [   18 72256]
# Cluster  0 : [    23 182945]
# Cluster  0 : [   18 28713]
# Cluster  0 : [  24 7193]
# Cluster  0 : [   31 54512]
# Cluster  0 : [   32 45882]
# Cluster  0 : [    32 109988]
# Cluster  0 : [    36 137249]
# Cluster  0 : [   22 37488]
# Cluster  0 : [   21 81804]
# Cluster  0 : [   20 74807]
# Cluster  0 : [   25 75006]
# Cluster  0 : [   25 80396]
# Cluster  0 : [   61 76425]
# Cluster  0 : [   20 71763]
# Cluster  0 : [    36 119596]
# Cluster  0 : [   21 36353]
# Cluster  0 : [    33 174577]
# Cluster  0 : [   25 26706]
# Cluster  0 : [    31 118340]
# Cluster  0 : [    29 160067]
# Cluster  0 : [    22 184743]
# Cluster  0 : [    23 111693]
# Cluster  0 : [   20 89838]
# Cluster  0 : [   30 15002]
# Cluster  0 : [   19 43617]
# Cluster  0 : [   25 73412]
# Cluster  0 : [   45 27440]
# Cluster  0 : [    22 155911]
# Cluster  0 : [   28 25531]
# Cluster  0 : [    29 125939]
# Cluster  0 : [   25 19435]
# Cluster  0 : [    58 170395]
# Cluster  0 : [    34 183616]
# Cluster  0 : [   25 99767]
# Cluster  0 : [   19 57449]
# Cluster  0 : [ 29 852]
# Cluster  0 : [  47 7175]
# Cluster  0 : [    37 169746]
# Cluster  0 : [    25 102264]
# Cluster  0 : [   24 25255]
# Cluster  0 : [   23 92551]
# Cluster  0 : [    28 123950]
# Cluster  0 : [   22 10364]
# Cluster  0 : [    36 128489]
# Cluster  0 : [    24 165845]
# Cluster  0 : [  42 6077]
# Cluster  0 : [    22 147157]
# Cluster  0 : [   40 54893]
# Cluster  0 : [    22 152569]
# Cluster  0 : [  22 3015]
# Cluster  0 : [   32 20112]
# Cluster  0 : [   24 11611]
# Cluster  0 : [    42 100372]
# Cluster  0 : [    20 141499]
# Cluster  0 : [   24 14635]
# Cluster  0 : [   19 95622]
# Cluster  0 : [    23 163308]
# Cluster  0 : [   23 63065]
# Cluster  0 : [   43 55400]
# Cluster  0 : [   18 72396]
# Cluster  0 : [    26 149738]
# Cluster  0 : [    57 163444]
# Cluster  0 : [    53 123267]
# Cluster  0 : [   37 54516]
# Cluster  0 : [    52 153785]
# Cluster  0 : [   21 76255]
# Cluster  0 : [   22 76005]
# Cluster  0 : [   45 42120]
# Cluster  0 : [    29 115629]
# Cluster  0 : [    24 125364]
# Cluster  0 : [    26 133422]
# Cluster  0 : [   39 18223]
# Cluster  0 : [    28 140031]
# Cluster  0 : [   25 28045]
# Cluster  0 : [    24 125845]
# Cluster  0 : [    32 176939]
# Cluster  0 : [   26 65152]
# Cluster  0 : [    33 111593]
# Cluster  0 : [   36 51384]
# Cluster  0 : [   19 95159]
# Cluster  0 : [   23 90390]
# Cluster  0 : [   26 69817]
# Cluster  0 : [    21 144616]
# Cluster  0 : [    24 130222]
# Cluster  0 : [    30 123571]
# Cluster  0 : [    23 102521]
# Cluster  0 : [   28 69352]
# Cluster  0 : [    23 150727]
# Cluster  0 : [   46 52081]
# Cluster  0 : [   28 34886]
# Cluster  0 : [    58 164234]
# Cluster  0 : [    30 100118]
# Cluster  0 : [    33 124182]
# Cluster  0 : [    36 121242]
# Cluster  0 : [    28 142278]
# Cluster  0 : [    23 161068]
# Cluster  0 : [  28 7091]
# Cluster  0 : [   26 28245]
# Cluster  0 : [    36 174105]
# Cluster  0 : [   28 21823]
# Cluster  0 : [   22 31882]
# Cluster  0 : [   49 76574]
# Cluster  0 : [    25 102618]
# Cluster  0 : [    40 138753]
# Cluster  0 : [    27 182834]
# Cluster  0 : [    30 152239]
# Cluster  0 : [   28 98298]
# Cluster  0 : [    34 119377]
# Cluster  0 : [  34 8439]
# Cluster  0 : [   38 16641]
# Cluster  0 : [   27 58713]
# Cluster  0 : [    25 142051]
# Cluster  0 : [    19 169231]
# Cluster  0 : [  27 3684]
# Cluster  0 : [   21 64803]
# Cluster  0 : [    20 113805]
# Cluster  0 : [    24 171046]
# Cluster  0 : [    16 139198]
# Cluster  0 : [   27 98249]
# Cluster  0 : [    49 152364]
# Cluster  0 : [    36 126563]
# Cluster  0 : [   31 59597]
# Cluster  0 : [   26 15645]
# Cluster  0 : [    28 151074]
# Cluster  0 : [    31 101854]
# Cluster  0 : [    28 171866]
# Cluster  0 : [    31 121502]
# Cluster  0 : [    19 137442]
# Cluster  0 : [   24 31793]
# ...
# Cluster  1 : [    34 340301]
# Cluster  1 : [    31 205622]
# Cluster  1 : [    20 343299]
# Cluster  1 : [    22 344440]
# Cluster  1 : [    22 198094]
# Cluster  1 : [    24 233409]
# Cluster  1 : [    27 372856]
# Cluster  1 : [    41 267869]
# Cluster  1 : [    23 217815]
# Cluster  1 : [    26 213162]
# Cluster  1 : [    38 274630]
# Cluster  1 : [    41 214516]
# Cluster  1 : [    26 186266]
# Cluster  1 : [    23 271159]
# Cluster  1 : [    37 334612]
# Cluster  1 : [    35 339422]
# Cluster  1 : [    21 369502]
# Cluster  1 : [    37 220619]
# Cluster  1 : [    26 287366]
# Cluster  1 : [    37 370822]
# Cluster  1 : [    29 303342]
# Cluster  1 : [    36 373385]
# Cluster  1 : [    26 206690]
# Cluster  1 : [    23 228618]
# Cluster  1 : [    45 280533]
# Cluster  1 : [    25 328687]
# Cluster  1 : [    29 331691]
# Cluster  1 : [    33 246612]
# Cluster  1 : [    25 336509]
# Cluster  1 : [    27 231691]
# Cluster  1 : [    36 266889]
# Cluster  1 : [    28 266720]
# Cluster  1 : [    19 284865]
# Cluster  1 : [    28 216616]
# Cluster  1 : [    28 245392]
# Cluster  1 : [    29 315668]
# Cluster  1 : [    35 245456]
# Cluster  1 : [    36 360244]
# Cluster  1 : [    18 225110]
# Cluster  1 : [    26 321814]
# Cluster  1 : [    18 309806]
# Cluster  1 : [    38 360150]
# Cluster  1 : [    25 220668]
# Cluster  1 : [    31 323367]
# Cluster  1 : [    40 347774]
# Cluster  1 : [    28 292899]
# Cluster  1 : [    24 331719]
# Cluster  1 : [    20 296316]
# Cluster  1 : [    30 205239]
# Cluster  1 : [    35 368782]
# Cluster  1 : [    30 362400]
# Cluster  1 : [    40 340654]
# Cluster  1 : [    40 348721]
# Cluster  1 : [    58 242907]
# Cluster  1 : [    40 277231]
# Cluster  1 : [    40 230393]
# Cluster  1 : [    29 315342]
# Cluster  1 : [    50 274817]
# Cluster  1 : [    31 294895]
# Cluster  1 : [    20 256212]
# Cluster  1 : [    26 196892]
# Cluster  1 : [    24 348960]
# Cluster  1 : [    38 232481]
# Cluster  1 : [    33 230332]
# Cluster  1 : [    24 303856]
# Cluster  1 : [    26 355814]
# Cluster  1 : [    21 355102]
# Cluster  1 : [    23 278977]
# Cluster  1 : [    27 207557]
# Cluster  1 : [    25 355446]
# Cluster  1 : [    29 227783]
# Cluster  1 : [    23 198512]
# Cluster  1 : [    31 232889]
# Cluster  1 : [    36 293072]
# Cluster  1 : [    25 273557]
# Cluster  1 : [    24 262192]
# Cluster  1 : [    53 219112]
# Cluster  1 : [    31 305448]
# Cluster  1 : [    31 264012]
# Cluster  1 : [    27 214925]
# Cluster  1 : [    30 198556]
# Cluster  1 : [    26 288895]
# Cluster  1 : [    26 240010]
# Cluster  1 : [    25 254536]
# Cluster  1 : [    36 226010]
# Cluster  1 : [    20 365884]
# Cluster  1 : [    26 367731]
# Cluster  1 : [    29 201733]
# Cluster  1 : [    21 363895]
# Cluster  1 : [    18 344721]
# Cluster  1 : [    19 364346]
# Cluster  1 : [    35 191701]
# Cluster  1 : [    25 340030]
# Cluster  1 : [    22 362412]
# Cluster  1 : [    35 204170]
# Cluster  1 : [    26 357174]
# Cluster  1 : [    56 359871]
# Cluster  1 : [    26 255079]
# Cluster  1 : [    19 273191]
# Cluster  1 : [    36 368549]
# Cluster  1 : [    22 359110]
# Cluster  1 : [    20 244859]
# Cluster  1 : [    37 315166]
# Cluster  1 : [    38 256354]
# Cluster  1 : [    23 210518]
# Cluster  1 : [    28 343977]
# Cluster  1 : [    24 334592]
# Cluster  1 : [    30 242027]
# Cluster  1 : [    24 188305]
# Cluster  1 : [    26 216053]
# Cluster  1 : [    34 320584]
# Cluster  1 : [    21 227513]
# Cluster  1 : [    21 215236]
# Cluster  1 : [    31 191710]
# Cluster  1 : [    31 272632]
# Cluster  1 : [    21 358333]
# Cluster  1 : [    17 278119]
# Cluster  1 : [    23 253961]
# Cluster  1 : [    21 337526]
# Cluster  1 : [    20 253254]
# Cluster  1 : [    37 224365]
# Cluster  1 : [    21 245650]
# Cluster  1 : [    22 306941]
# Cluster  1 : [    28 220356]
# Cluster  1 : [    21 222353]
# Cluster  1 : [    21 252351]
# Cluster  1 : [    31 326081]
# Cluster  1 : [    20 257906]
# Cluster  1 : [    33 297931]
# Cluster  1 : [    27 365260]
# Cluster  1 : [    56 333741]
# Cluster  1 : [    52 274391]
# Cluster  1 : [    34 215479]
# Cluster  1 : [    52 292034]
# Cluster  1 : [    32 241330]
# Cluster  1 : [    34 301684]
# Cluster  1 : [    35 290728]
# Cluster  1 : [    40 363720]
# Cluster  1 : [    26 255942]
# Cluster  1 : [    54 300207]
# Cluster  1 : [    17 252098]
# Cluster  1 : [    28 233483]
# Cluster  1 : [    30 231767]
# Cluster  1 : [    25 257821]
# Cluster  1 : [    32 197869]
# Cluster  1 : [    50 293927]
# Cluster  1 : [    47 235519]
# Cluster  1 : [    27 204469]
# Cluster  1 : [    43 282642]
# Cluster  1 : [    20 306937]
# Cluster  1 : [    21 334569]
# Cluster  1 : [    20 326951]
# Cluster  1 : [    18 304799]
# Cluster  1 : [    23 234255]
# Cluster  1 : [    59 186071]
# Cluster  1 : [    18 267974]
# Cluster  1 : [    47 212307]
# Cluster  1 : [    28 350274]
# Cluster  1 : [    31 349944]
# Cluster  1 : [    16 277797]
# Cluster  1 : [    31 324182]
# Cluster  1 : [    19 316226]
# Cluster  1 : [    21 187516]
# Cluster  1 : [    21 227055]
# Cluster  1 : [    29 312338]
# Cluster  1 : [    58 361925]
# Cluster  1 : [    28 224346]
# Cluster  1 : [    24 201489]
# Cluster  1 : [    37 356428]
# Cluster  1 : [    19 212519]
# Cluster  1 : [    36 200929]
# Cluster  1 : [    42 346995]
# Cluster  1 : [    33 203071]
# Cluster  1 : [    54 217359]
# Cluster  1 : [    23 299863]
# Cluster  1 : [    19 351963]
# Cluster  1 : [    20 317246]
# Cluster  1 : [    35 263877]
# Cluster  1 : [    25 216765]
# Cluster  1 : [    19 333966]
# Cluster  1 : [    31 368454]
# Cluster  1 : [    26 317281]
# Cluster  1 : [    19 259584]
# Cluster  1 : [    25 204903]
# Cluster  1 : [    34 241012]
# Cluster  1 : [    27 241621]
# Cluster  1 : [    20 334367]
# Cluster  1 : [    20 203690]
# Cluster  1 : [    28 187363]
# Cluster  1 : [    22 245670]
# Cluster  1 : [    22 328968]
# Cluster  1 : [    31 215258]
# Cluster  1 : [    22 291353]
# Cluster  1 : [    50 225612]
# Cluster  1 : [    17 265612]
# Cluster  1 : [    49 287969]
# Cluster  1 : [    33 198546]
# Cluster  1 : [    33 296482]
# Cluster  1 : [    21 296306]
# Cluster  1 : [    54 247744]
# Cluster  1 : [    22 236935]
# Cluster  1 : [    38 242604]
# Cluster  1 : [    58 347403]
# Cluster  1 : [    28 246890]
# Cluster  1 : [    41 338391]
# Cluster  1 : [    34 311419]
# Cluster  1 : [    48 250046]
# Cluster  1 : [    23 339956]
# Cluster  1 : [    41 190373]
# Cluster  1 : [    31 271709]
# Cluster  1 : [    41 328651]
# Cluster  1 : [    34 291049]
# Cluster  1 : [    25 230296]
# Cluster  1 : [    20 290044]
# Cluster  1 : [    27 361466]
# Cluster  1 : [    28 237695]
# Cluster  1 : [    26 267631]
# Cluster  1 : [    27 361299]
# Cluster  1 : [    40 355109]
# Cluster  1 : [    30 234436]
# Cluster  1 : [    31 212554]
# Cluster  1 : [    24 354138]
# Cluster  1 : [    20 193180]
# Cluster  1 : [    20 269759]
# Cluster  1 : [    19 303450]
# Cluster  1 : [    27 280992]
# Cluster  1 : [    44 252051]
# Cluster  1 : [    18 355370]
# Cluster  1 : [    48 286529]
# Cluster  1 : [    40 212096]
# Cluster  1 : [    19 306191]
# Cluster  1 : [    52 332561]
# Cluster  1 : [    22 257240]
# Cluster  1 : [    19 242709]
# Cluster  1 : [    20 301435]
# Cluster  1 : [    24 322550]
# Cluster  1 : [    23 226424]
# Cluster  1 : [    24 335846]
# Cluster  1 : [    21 188472]
# Cluster  1 : [    35 276044]
# Cluster  1 : [    21 286255]
# Cluster  1 : [    34 269699]
# Cluster  1 : [    36 290709]
# Cluster  1 : [    17 338765]
# Cluster  1 : [    23 218396]
# Cluster  1 : [    49 230141]
# Cluster  1 : [    41 203816]
# Cluster  1 : [    37 224473]
# Cluster  1 : [    48 330592]
# Cluster  1 : [    25 311030]
# Cluster  1 : [    30 355888]
# Cluster  1 : [    34 330632]
# Cluster  1 : [    27 313522]
# Cluster  1 : [    28 307497]
# Cluster  1 : [    26 247548]
# Cluster  1 : [    24 335206]
# Cluster  1 : [    25 187707]
# Cluster  1 : [    41 232636]
# Cluster  1 : [    44 189530]
# Cluster  1 : [    20 332177]
# Cluster  1 : [    26 237795]
# Cluster  1 : [    52 288849]
# Cluster  1 : [    24 316809]
# Cluster  1 : [    42 289211]
# Cluster  1 : [    27 246183]
# Cluster  1 : [    27 353131]
# Cluster  1 : [    32 239711]
# Cluster  1 : [    19 299032]
# Cluster  1 : [    55 362926]
# Cluster  1 : [    27 246317]
# Cluster  1 : [    33 273601]
# Cluster  1 : [    27 220279]
# Cluster  1 : [    24 194955]
# Cluster  1 : [    23 223500]
# Cluster  1 : [    23 227581]
# Cluster  1 : [    26 246538]
# Cluster  1 : [    47 245952]
# Cluster  1 : [    27 204900]
# Cluster  1 : [    24 335253]
# Cluster  1 : [    45 340534]
# Cluster  1 : [    28 331582]
# Cluster  1 : [    23 328287]
# Cluster  1 : [    28 363331]
# Cluster  1 : [    34 292606]
# Cluster  1 : [    27 316338]
# Cluster  1 : [    38 339487]
# Cluster  1 : [    21 264958]
# Cluster  1 : [    39 224707]
# Cluster  1 : [    19 196495]
# Cluster  1 : [    42 352088]
# Cluster  1 : [    30 311892]
# Cluster  1 : [    24 267042]
# Cluster  1 : [    42 221838]
# Cluster  1 : [    41 274268]
# Cluster  1 : [    30 209487]
# Cluster  1 : [    18 280818]
# Cluster  1 : [    18 343187]
# Cluster  1 : [    19 201951]
# Cluster  1 : [    25 242417]
# Cluster  1 : [    32 262629]
# Cluster  1 : [    28 365501]
# Cluster  1 : [    26 278238]
# Cluster  1 : [    37 283518]
# Cluster  1 : [    31 241614]
# Cluster  1 : [    23 267912]
# Cluster  1 : [    32 244826]
# Cluster  1 : [    47 337475]
# Cluster  1 : [    35 186691]
# Cluster  1 : [    29 342674]
# Cluster  1 : [    24 277626]
# Cluster  1 : [    33 327977]
# Cluster  1 : [    18 302316]
# Cluster  1 : [    28 322809]
# Cluster  1 : [    21 340636]
# Cluster  1 : [    28 326909]
# Cluster  1 : [    45 207853]
# Cluster  1 : [    35 277478]
# Cluster  1 : [    20 285159]
# Cluster  1 : [    47 196818]
# Cluster  1 : [    37 217799]
# Cluster  1 : [    47 216288]
# Cluster  1 : [    31 190986]
# Cluster  1 : [    25 364057]
# Cluster  1 : [    26 220915]
# Cluster  1 : [    40 276082]
# Cluster  1 : [    35 212562]
# Cluster  1 : [    24 296845]
# Cluster  1 : [    31 303377]
# Cluster  1 : [    37 243022]
# Cluster  1 : [    22 254367]
# Cluster  1 : [    64 370846]
# Cluster  1 : [    42 287895]
# Cluster  1 : [    23 322488]
# Cluster  1 : [    27 343380]
# Cluster  1 : [    21 245881]
# Cluster  1 : [    34 262237]
# Cluster  1 : [    19 225058]
# Cluster  1 : [    31 341236]
# Cluster  1 : [    21 368202]
# Cluster  1 : [    31 300631]
# Cluster  1 : [    34 353205]
# Cluster  1 : [    23 229265]
# Cluster  1 : [    31 187016]
# Cluster  1 : [    27 296596]
# Cluster  1 : [    36 246208]
# Cluster  1 : [    25 266036]
# Cluster  1 : [    54 202511]
# Cluster  1 : [    46 256284]
# Cluster  1 : [    17 343563]
# Cluster  1 : [    21 337238]
# Cluster  1 : [    28 228882]
# Cluster  1 : [    21 358343]
# Cluster  1 : [    23 302918]
# Cluster  1 : [    32 228544]
# Cluster  1 : [    39 356699]
# Cluster  1 : [    45 186742]
# Cluster  1 : [    25 265703]
# Cluster  1 : [    35 353966]
# Cluster  1 : [    42 195454]
# Cluster  1 : [    27 242978]
# Cluster  1 : [    23 326970]
# Cluster  1 : [    23 234940]
# Cluster  1 : [    32 219634]
# Cluster  1 : [    32 314825]
# Cluster  1 : [    24 348559]
# Cluster  1 : [    24 188752]
# Cluster  1 : [    17 223328]
# Cluster  1 : [    36 336395]
# Cluster  1 : [    55 228773]
# Cluster  1 : [    36 192523]
# Cluster  1 : [    25 329597]
# Cluster  1 : [    27 330805]
# Cluster  1 : [    25 337954]
# Cluster  1 : [    28 204400]
# Cluster  1 : [    25 257214]
# Cluster  1 : [    47 308070]
# Cluster  1 : [    35 256167]
# Cluster  1 : [    62 273440]
# Cluster  1 : [    36 300643]
# Cluster  1 : [    57 243670]
# Cluster  1 : [    17 206085]
# Cluster  1 : [    21 297336]
# Cluster  1 : [    35 310862]
# Cluster  1 : [    31 363307]
# Cluster  1 : [    19 311273]
# Cluster  1 : [    22 220003]
# Cluster  1 : [    46 302187]
# Cluster  1 : [    23 273224]
# Cluster  1 : [    27 360238]
# Cluster  1 : [    19 364745]
# Cluster  1 : [    23 357399]
# Cluster  1 : [    26 309059]
# Cluster  1 : [    51 350377]
# Cluster  1 : [    30 341812]
# Cluster  1 : [    33 318634]
# Cluster  1 : [    22 268521]
# Cluster  1 : [    30 366567]
# Cluster  1 : [    46 194883]
# Cluster  1 : [    39 192334]
# Cluster  1 : [    25 187528]
# Cluster  1 : [    24 317582]
# Cluster  1 : [    20 314485]
# Cluster  1 : [    23 241019]
# Cluster  1 : [    59 251958]
# Cluster  1 : [    57 262058]
# Cluster  1 : [    51 365607]
# Cluster  1 : [    27 355298]
# Cluster  1 : [    29 260628]
# Cluster  1 : [    26 336424]
# Cluster  1 : [    43 230933]
# Cluster  1 : [    40 280425]
# Cluster  1 : [    34 190975]
# Cluster  1 : [    31 210707]
# Cluster  1 : [    32 370948]
# Cluster  1 : [    34 316828]
# Cluster  1 : [    18 321272]
# Cluster  1 : [    36 218826]
# Cluster  1 : [    41 215073]
# Cluster  1 : [    23 277425]
# Cluster  1 : [    47 319082]
# Cluster  1 : [    32 345992]
# Cluster  1 : [    21 300310]
# Cluster  1 : [    30 361569]
# Cluster  1 : [    23 306989]
# Cluster  1 : [    22 334584]
# Cluster  1 : [    34 261042]
# Cluster  1 : [    25 209126]
# Cluster  1 : [    73 299451]
# Cluster  1 : [    23 224589]
# Cluster  1 : [    27 268168]
# Cluster  1 : [    26 367847]
# Cluster  1 : [    21 360031]
# Cluster  1 : [    34 257522]
# Cluster  1 : [    20 364209]
# Cluster  1 : [    30 281192]
# Cluster  1 : [    26 189898]
# Cluster  1 : [    41 332427]
# Cluster  1 : [    22 253063]
# Cluster  1 : [    31 304460]
# Cluster  1 : [    32 367798]
# Cluster  1 : [    31 201483]
# Cluster  1 : [    28 316948]
# Cluster  1 : [    27 201082]
# Cluster  1 : [    38 348907]
# Cluster  1 : [    17 352373]
# Cluster  1 : [    27 355601]
# Cluster  1 : [    28 310267]
# Cluster  1 : [    25 331026]
# Cluster  1 : [    22 213717]
# Cluster  1 : [    40 362036]
# Cluster  1 : [    37 358583]
# Cluster  1 : [    29 366788]
# Cluster  1 : [    25 289108]
# Cluster  1 : [    27 370522]
# Cluster  1 : [    48 337688]
# Cluster  1 : [    23 262628]
# Cluster  1 : [    34 291336]
# Cluster  1 : [    43 311469]
# Cluster  1 : [    36 213159]
# Cluster  1 : [    24 244545]
# Cluster  1 : [    33 266946]
# Cluster  1 : [    34 270711]
# Cluster  1 : [    26 249984]
# Cluster  1 : [    22 334554]
# Cluster  1 : [    23 187558]
# Cluster  1 : [    21 347171]
# Cluster  1 : [    23 358535]
# Cluster  1 : [    32 258100]
# Cluster  1 : [    23 244242]
# Cluster  1 : [    42 239055]
# Cluster  1 : [    45 344855]
# Cluster  1 : [    25 314914]
# Cluster  1 : [    26 344243]
# Cluster  1 : [    66 270281]
# Cluster  1 : [    23 207739]
# Cluster  1 : [    38 186397]
# Cluster  1 : [    22 351431]
# Cluster  1 : [    32 227511]
# Cluster  1 : [    25 347568]
# Cluster  1 : [    45 246002]
# Cluster  1 : [    39 371481]
# Cluster  1 : [    29 346959]
# Cluster  1 : [    38 317148]
# Cluster  1 : [    20 299628]
# Cluster  1 : [    27 318734]
# Cluster  1 : [    34 311093]
# Cluster  1 : [    29 201669]
# Cluster  1 : [    22 284411]
# Cluster  1 : [    30 253386]
# Cluster  1 : [    34 347011]
# Cluster  1 : [    23 240226]
# Cluster  1 : [    40 243610]
# Cluster  1 : [    19 217327]
# Cluster  1 : [    23 354555]
# Cluster  1 : [    52 193070]
# Cluster  1 : [    29 204528]
# Cluster  1 : [    17 208991]
# Cluster  1 : [    22 188652]
# Cluster  1 : [    42 238369]
# Cluster  1 : [    20 212910]
# Cluster  1 : [    24 211337]
# Cluster  1 : [    28 234740]
# Cluster  1 : [    25 262567]
# Cluster  1 : [    32 365552]
# Cluster  1 : [    22 297840]
# Cluster  1 : [    22 232468]
# Cluster  1 : [    38 357737]
# Cluster  1 : [    21 335326]
# Cluster  1 : [    63 241571]
# Cluster  1 : [    23 246830]
# Cluster  1 : [    29 286911]
# Cluster  1 : [    27 206946]
# Cluster  1 : [    38 339249]
# Cluster  1 : [    26 275260]
# Cluster  1 : [    29 281470]
# Cluster  1 : [    39 190854]
# Cluster  1 : [    31 258999]
# Cluster  1 : [    20 341020]
# Cluster  1 : [    25 215529]
# Cluster  1 : [    22 186542]
# Cluster  1 : [    27 186578]
# Cluster  1 : [    27 195970]
# Cluster  1 : [    38 215927]
# Cluster  1 : [    36 369288]
# Cluster  1 : [    27 186646]
# Cluster  1 : [    35 243560]
# Cluster  1 : [    20 349700]
# Cluster  1 : [    47 278606]
# Cluster  1 : [    30 320373]
# Cluster  1 : [    34 204699]
# Cluster  1 : [    40 295861]
# Cluster  1 : [    42 356425]
# Cluster  1 : [    25 366086]
# Cluster  1 : [    24 198753]
# Cluster  1 : [    29 232937]
# Cluster  1 : [    23 268101]
# Cluster  1 : [    39 226880]
# Cluster  1 : [    53 260088]
# Cluster  1 : [    26 312873]
# Cluster  1 : [    23 246045]
# Cluster  1 : [    28 319766]
# Cluster  1 : [    36 346524]
# Cluster  1 : [    20 357123]
# Cluster  1 : [    32 188200]
# Cluster  1 : [    22 272901]
# Cluster  1 : [    20 275369]
# Cluster  1 : [    34 193251]
# Cluster  1 : [    39 213853]
# Cluster  1 : [    26 352309]
# Cluster  1 : [    22 246740]
# Cluster  1 : [    40 260880]

# %%
print('number of users which the avarage of them age = 48 : ', counter0)
print('number of users which the avarage of them age = 23 : ', counter1)
# Out:
# number of users which the avarage of them age = 48 :  1829
# number of users which the avarage of them age = 23 :  1916
